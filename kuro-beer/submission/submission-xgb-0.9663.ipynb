# %% [markdown]
# # next-prev-channel

# %%
import gc
import time
import numpy as np
import pandas as pd
import xgboost as xgb
from xgboost import plot_importance
import matplotlib.pyplot as plt
import click
from logzero import logger

# %%
# %%time
click_data = pd.read_feather("../data/merge.feather", nthreads=40)
# Out:
# CPU times: user 12.9 s, sys: 8.81 s, total: 21.7 s
# Wall time: 1.63 s

# %%
click_data.shape
# Out:
# (145713707, 37)

# %%
click_data.dtypes
# Out:
# app                                                uint16
# channel                                            uint16
# click_id                                           uint32
# device                                             uint16
# ip                                                 uint32
# is_attributed                                       uint8
# os                                                 uint16
# click_time                                 datetime64[ns]
# is_test                                              bool
# dow                                                 uint8
# hour                                                uint8
# minute                                              uint8
# min5                                                uint8
# second                                              uint8
# sin_time                                          float64
# cos_time                                          float64
# ip_os_device                                       uint64
# ip_os_device_dow_hour                              uint64
# ip_os_device_dow_hour_min5                         uint64
# ip_os_device_app_encoded                           uint32
# ip_os_device_channel_encoded                       uint32
# count_by_ip_os_device_dow_hour                     uint32
# count_by_ip_os_device_dow_hour_min5                uint32
# app_variety_ip_os_device_dow_hour                  uint16
# chan_variety_ip_os_device_dow_hour                 uint16
# app_variety_ip_os_device_dow_hour_min5             uint16
# chan_variety_ip_os_device_dow_hour_min5            uint16
# rank_by_ip_os_device_dow_hour                      uint32
# rank_by_ip_os_device_dow_hour_min5                 uint32
# click_time_prev                            datetime64[ns]
# app_prev                                           uint16
# channel_prev                                       uint16
# interval_prev                                      uint16
# click_time_next                            datetime64[ns]
# app_next                                           uint16
# channel_next                                       uint16
# interval_next                                      uint16
# dtype: object

# %%
# %%time
logger.info("Splitting data...")
click_data.drop(columns=["click_id", "click_time", "click_time_prev", "click_time_next"], inplace=True)
train = click_data[click_data["dow"] < 3]
valid = click_data[click_data["dow"] == 3]

del click_data
gc.collect()
# Out:
# [I 180501 13:58:35 <timed exec>:1] Splitting data...
# CPU times: user 18.3 s, sys: 10.8 s, total: 29.1 s
# Wall time: 29.1 s

# %%
# %%time
y_train = train["is_attributed"].astype("int")
train.drop(columns=["is_attributed"], inplace=True)
y_valid = valid["is_attributed"].astype("int")
valid.drop(columns=["is_attributed"], inplace=True)
gc.collect()
# Out:
# CPU times: user 5.83 s, sys: 4.58 s, total: 10.4 s
# Wall time: 10.4 s

# %%
# %%time
logger.info("Generating matrix...")
dtrain = xgb.DMatrix(train, y_train, nthread=40)
del train, y_train
gc.collect()

dvalid = xgb.DMatrix(valid, y_valid, nthread=40)
del valid, y_valid
gc.collect()
# Out:
# [I 180501 13:59:14 <timed exec>:1] Generating matrix...
# CPU times: user 4min 56s, sys: 1min 47s, total: 6min 44s
# Wall time: 5min

# %%
# %%time
n_thread = 40
logger.info("Validating...")
params = {'eta': 0.2,
          'tree_method': "hist",
          'grow_policy': "lossguide",
#           'max_leaves': 7,
          'max_depth': 5,
          'subsample': 0.7,
          'colsample_bytree': 0.7,
          'colsample_bylevel': 0.7,
          'min_child_weight': 0,
          'alpha': 4,
          'objective': 'binary:logistic',
          'scale_pos_weight': 99,
          'eval_metric': 'auc',
          'nthread': n_thread,
          'random_state': 99,
          'silent': True}
watchlist = [(dtrain, 'train'), (dvalid, 'valid')]
model = xgb.train(params,
                  dtrain,
                  200,
                  watchlist,
                  maximize=True,
                  early_stopping_rounds=25,
                  verbose_eval=5)
# Out:
# [I 180501 14:04:15 <timed exec>:2] Validating...
# [0]	train-auc:0.956312	valid-auc:0.946037
# Multiple eval metrics have been passed: 'valid-auc' will be used for early stopping.
#
# Will train until valid-auc hasn't improved in 25 rounds.
# [5]	train-auc:0.961003	valid-auc:0.950372
# [10]	train-auc:0.964338	valid-auc:0.953913
# [15]	train-auc:0.968985	valid-auc:0.960136
# [20]	train-auc:0.970784	valid-auc:0.962151
# [25]	train-auc:0.972246	valid-auc:0.964058
# [30]	train-auc:0.973453	valid-auc:0.965593
# [35]	train-auc:0.974321	valid-auc:0.966821
# [40]	train-auc:0.974907	valid-auc:0.967256
# [45]	train-auc:0.975529	valid-auc:0.968037
# [50]	train-auc:0.975934	valid-auc:0.968335
# [55]	train-auc:0.97627	valid-auc:0.968704
# [60]	train-auc:0.976653	valid-auc:0.968973
# [65]	train-auc:0.97694	valid-auc:0.969281
# [70]	train-auc:0.977271	valid-auc:0.969602
# [75]	train-auc:0.977613	valid-auc:0.96983
# [80]	train-auc:0.977901	valid-auc:0.97006
# [85]	train-auc:0.978146	valid-auc:0.970238
# [90]	train-auc:0.978301	valid-auc:0.970374
# [95]	train-auc:0.978533	valid-auc:0.970503
# [100]	train-auc:0.978688	valid-auc:0.970545
# [105]	train-auc:0.978848	valid-auc:0.970658
# [110]	train-auc:0.979003	valid-auc:0.970784
# [115]	train-auc:0.979147	valid-auc:0.970901
# [120]	train-auc:0.979289	valid-auc:0.971025
# [125]	train-auc:0.979414	valid-auc:0.971093
# [130]	train-auc:0.979553	valid-auc:0.971215
# [135]	train-auc:0.979669	valid-auc:0.971286
# [140]	train-auc:0.97977	valid-auc:0.971377
# [145]	train-auc:0.979876	valid-auc:0.971418
# [150]	train-auc:0.980018	valid-auc:0.97151
# [155]	train-auc:0.980149	valid-auc:0.971615
# [160]	train-auc:0.980246	valid-auc:0.971649
# [165]	train-auc:0.980359	valid-auc:0.971682
# [170]	train-auc:0.98045	valid-auc:0.971761
# [175]	train-auc:0.980608	valid-auc:0.971831
# [180]	train-auc:0.980704	valid-auc:0.971916
# [185]	train-auc:0.980798	valid-auc:0.971941
# [190]	train-auc:0.980914	valid-auc:0.971988
# [195]	train-auc:0.981008	valid-auc:0.972025
# [199]	train-auc:0.981083	valid-auc:0.972058
# CPU times: user 9h 59min 48s, sys: 25min, total: 10h 24min 49s
# Wall time: 30min 7s

# %%
fig, ax = plt.subplots(figsize=(12,18))
xgb.plot_importance(model, max_num_features=50, height=0.8, ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,18))
xgb.plot_importance(model, max_num_features=50, height=0.8, ax=ax, importance_type='gain')
plt.show()

# %%
# %%time
click_data = pd.read_feather("../data/merge.feather", nthreads=40)
# Out:
# CPU times: user 13.3 s, sys: 8.24 s, total: 21.6 s
# Wall time: 1.58 s

# %%
test = click_data[click_data.is_test == True]
sub = pd.DataFrame()
sub["click_id"] = test["click_id"].astype("int")
test.drop(columns=["is_attributed", "click_id", "click_time", "click_time_prev", "click_time_next"], inplace=True)
print(sub.shape, test.shape)
# Out:
# (18790469, 1) (18790469, 32)
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
logger.info("Generating matrix...")
dtest = xgb.DMatrix(test)
del test
gc.collect()
# Out:
# [I 180501 14:34:32 <ipython-input-13-79999e7ff128>:1] Generating matrix...
# 0

# %%
logger.info("Predicting...")
sub['is_attributed'] = model.predict(dtest, ntree_limit=model.best_ntree_limit)
sub.to_csv('xgb_sub.csv', index=False)
# Out:
# [I 180501 14:35:15 <ipython-input-14-c02fda1fc7b4>:1] Predicting...

# %%
print(model.best_ntree_limit)
# Out:
# 200

# %%
sub.sort_values('click_id')
# Out:
#            click_id  is_attributed
# 126923238         0       0.079506
# 126923241         1       0.049038
# 126923258         2       0.007831
# 126923327         3       0.015665
# 126923425         4       0.018216
# 126923452         5       0.062694
# 126923472         6       0.007762
# 126923478         7       0.037402
# 126923502         8       0.020091
# 126923501         9       0.056694
# 126923503        10       0.094145
# 126923528        11       0.019071
# 126924171        12       0.025441
# 126924233        13       0.203574
# 126924250        14       0.013883
# 126924255        15       0.000556
# 126924295        16       0.064757
# 126924325        17       0.004507
# 126924345        18       0.002051
# 126924296        19       0.049164
# 126924256        20       0.000828
# 126924354        21       0.205636
# 126924356        22       0.020967
# 126924393        23       0.019381
# 126924410        24       0.000147
# 126924430        25       0.038361
# 126924468        26       0.006762
# 126924482        27       0.044947
# 126924907        28       0.007320
# 126924918        29       0.022158
# ...             ...            ...
# 143284150  18790439       0.005928
# 143542693  18790440       0.003384
# 143881746  18790441       0.028161
# 145324439  18790442       0.001698
# 145484067  18790443       0.004658
# 145551037  18790444       0.008000
# 142506803  18790445       0.013380
# 145711845  18790446       0.000929
# 143889033  18790447       0.010640
# 142725672  18790448       0.012400
# 143489660  18790449       0.005467
# 145713706  18790450       0.003223
# 145713593  18790451       0.005649
# 142857644  18790452       0.010436
# 142857645  18790453       0.039863
# 142857646  18790454       0.072343
# 145541871  18790455       0.008546
# 145705261  18790456       0.048287
# 142857647  18790457       0.207034
# 143337747  18790458       0.005295
# 142917209  18790459       0.002790
# 143045819  18790460       0.028287
# 143154493  18790461       0.006855
# 145249324  18790462       0.003643
# 144122889  18790463       0.004017
# 145372213  18790464       0.046767
# 145709167  18790465       0.000975
# 145708357  18790466       0.007712
# 143284151  18790467       0.008273
# 142538302  18790468       0.000810
#
# [18790469 rows x 2 columns]
