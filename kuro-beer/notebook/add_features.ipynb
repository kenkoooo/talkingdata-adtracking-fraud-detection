# %%
import gc
import time
import numpy as np
import pandas as pd
import xgboost as xgb
from xgboost import plot_importance
import matplotlib.pyplot as plt
from logzero import logger

# %%
def do_count(df, group_cols, agg_type='uint32'):
    agg_name = "_".join(group_cols) + "_count"
    print("Aggregating by ", group_cols, '...')
    gp = df[group_cols][group_cols].groupby(group_cols).size().rename(agg_name).to_frame().reset_index()
    df = df.merge(gp, on=group_cols, how='left')
    del gp
    print(agg_name + " max value = ", df[agg_name].max())
    df[agg_name] = df[agg_name].astype(agg_type)
    gc.collect()
    return(df)


def do_countuniq(df, group_cols, counted, agg_type='uint32'):
    agg_name = "_".join(group_cols) + "_{}_countuniq".format(counted)
    print("Counting unqiue ", counted, " by ", group_cols, '...')
    gp = df[group_cols+[counted]].groupby(group_cols)[counted].nunique().reset_index().rename(columns={counted: agg_name})
    df = df.merge(gp, on=group_cols, how='left')
    del gp
    print(agg_name + " max value = ", df[agg_name].max())
    df[agg_name] = df[agg_name].astype(agg_type)
    gc.collect()
    return(df)


def do_cumcount(df, group_cols, counted, agg_type='uint32'):
    agg_name = "_".join(group_cols) + "_cumcount"
    print("Cumulative count by ", group_cols, '...')
    gp = df[group_cols+[counted]].groupby(group_cols)[counted].cumcount()
    df[agg_name] = gp.values
    del gp
    print(agg_name + " max value = ", df[agg_name].max())
    df[agg_name] = df[agg_name].astype(agg_type)
    gc.collect()
    return(df)


def do_mean(df, group_cols, counted, agg_type='float32'):
    agg_name = "_".join(group_cols) + "_mean"
    print("Calculating mean of ", counted, " by ", group_cols, '...')
    gp = df[group_cols + [counted]].groupby(group_cols)[counted].mean(
    ).reset_index().rename(columns={counted: agg_name})
    df = df.merge(gp, on=group_cols, how='left')
    del gp
    print(agg_name + " max value = ", df[agg_name].max())
    df[agg_name] = df[agg_name].astype(agg_type)
    gc.collect()
    return(df)


def do_var(df, group_cols, counted, agg_type='float32'):
    agg_name = "_".join(group_cols) + "_var"
    print("Calculating variance of ", counted, " by ", group_cols, '...')
    gp = df[group_cols + [counted]].groupby(group_cols)[counted].var(
    ).reset_index().rename(columns={counted: agg_name})
    df = df.merge(gp, on=group_cols, how='left')
    del gp
    print(agg_name + " max value = ", df[agg_name].max())
    df[agg_name] = df[agg_name].astype(agg_type)
    gc.collect()
    return(df)

# %%
# %%time
df = pd.read_feather("../data/merged_click_data.hdf", "merged_click_data")
# Out:
# CPU times: user 52 ms, sys: 8.52 s, total: 8.57 s
# Wall time: 8.57 s

# %%
df.dtypes
# Out:
# app                                              uint16
# channel                                          uint16
# click_id                                        float64
# device                                           uint16
# ip                                               uint32
# is_attributed                                   float64
# os                                               uint16
# click_count_by_ip_os_device_dow                  uint32
# click_count_by_ip_os_device_dow_hour             uint16
# click_count_by_ip                                uint32
# dow                                               uint8
# hour                                              uint8
# minute                                            uint8
# second                                            uint8
# rank_by_ip                                       uint32
# rank_by_ip_os_device                             uint32
# rank_by_ip_os_device_dow                         uint32
# click_time_interval_by_ip                       float64
# click_time_interval_by_ip_os_device             float64
# click_time_interval_by_ip_os_device_dow         float64
# click_time_interval_by_ip_os_device_dow_hour    float64
# dtype: object

# %%
# %%time
df = do_cumcount(df, ['ip', 'device', 'os'], 'app')
gc.collect()
df = do_cumcount(df, ['ip'], 'os')
gc.collect()
df = do_countuniq(df, ['ip'], 'channel', 'uint8')
gc.collect()
df = do_countuniq(df, ['ip', 'dow'], 'hour', 'uint8')
gc.collect()
df = do_countuniq(df, ['ip'], 'app', 'uint8')
gc.collect()
df = do_countuniq(df, ['ip', 'app'], 'os', 'uint8')
gc.collect()
df = do_countuniq(df, ['ip'], 'device', 'uint16')
gc.collect()
df = do_countuniq(df, ['app'], 'channel')
gc.collect()
df = do_countuniq(df, ['ip', 'device', 'os'], 'app')
gc.collect()
df = do_count(df, ['ip', 'dow', 'hour'])
gc.collect()
df = do_count(df, ['ip', 'app'])
gc.collect()
df = do_count(df, ['ip', 'app', 'os'], 'uint16')
gc.collect()
df = do_var(df, ['ip', 'dow', 'channel'], 'hour')
gc.collect()
df = do_var(df, ['ip', 'app', 'os'], 'hour')
gc.collect()
df = do_var(df, ['ip', 'app', 'channel'], 'dow')
gc.collect()
df = do_mean(df, ['ip', 'app', 'channel'], 'hour')
gc.collect()
# Out:
# Cumulative count by  ['ip', 'device', 'os'] ...
# ip_device_os_cumcount max value =  282426
# Cumulative count by  ['ip'] ...
# ip_cumcount max value =  1421255
# Counting unqiue  channel  by  ['ip'] ...
# ip_channel_countuniq max value =  165
# Counting unqiue  hour  by  ['ip', 'dow'] ...
# ip_dow_hour_countuniq max value =  24
# Counting unqiue  app  by  ['ip'] ...
# ip_app_countuniq max value =  277
# Counting unqiue  os  by  ['ip', 'app'] ...
# ip_app_os_countuniq max value =  148
# Counting unqiue  device  by  ['ip'] ...
# ip_device_countuniq max value =  551
# Counting unqiue  channel  by  ['app'] ...
# app_channel_countuniq max value =  49
# Counting unqiue  app  by  ['ip', 'device', 'os'] ...
# ip_device_os_app_countuniq max value =  100
# Aggregating by  ['ip', 'dow', 'hour'] ...
# ip_dow_hour_count max value =  44259
# Aggregating by  ['ip', 'app'] ...
# ip_app_count max value =  220743
# Aggregating by  ['ip', 'app', 'os'] ...
# ip_app_os_count max value =  55159
# Calculating variance of  hour  by  ['ip', 'dow', 'channel'] ...
# ip_dow_channel_var max value =  264.5
# Calculating variance of  hour  by  ['ip', 'app', 'os'] ...
# ip_app_os_var max value =  264.5
# Calculating variance of  dow  by  ['ip', 'app', 'channel'] ...
# ip_app_channel_var max value =  8.0
# Calculating mean of  hour  by  ['ip', 'app', 'channel'] ...
# ip_app_channel_mean max value =  23.0
# CPU times: user 54min 14s, sys: 18min 18s, total: 1h 12min 33s
# Wall time: 1h 12min 32s

# %%
df.columns
# Out:
# Index(['app', 'channel', 'click_id', 'device', 'ip', 'is_attributed', 'os',
#        'click_count_by_ip_os_device_dow',
#        'click_count_by_ip_os_device_dow_hour', 'click_count_by_ip', 'dow',
#        'hour', 'minute', 'second', 'rank_by_ip', 'rank_by_ip_os_device',
#        'rank_by_ip_os_device_dow', 'click_time_interval_by_ip',
#        'click_time_interval_by_ip_os_device',
#        'click_time_interval_by_ip_os_device_dow',
#        'click_time_interval_by_ip_os_device_dow_hour', 'ip_device_os_cumcount',
#        'ip_cumcount', 'ip_channel_countuniq', 'ip_dow_hour_countuniq',
#        'ip_app_countuniq', 'ip_app_os_countuniq', 'ip_device_countuniq',
#        'app_channel_countuniq', 'ip_device_os_app_countuniq',
#        'ip_dow_hour_count', 'ip_app_count', 'ip_app_os_count',
#        'ip_dow_channel_var', 'ip_app_os_var', 'ip_app_channel_var',
#        'ip_app_channel_mean'],
#       dtype='object')

# %%
df
# Out:
#            app  channel    click_id  device      ip  is_attributed  os  \
# 0            3      379         NaN       1   83230            0.0  13
# 1            3      379         NaN       1   17357            0.0  19
# 2            3      379         NaN       1   35810            0.0  13
# 3           14      478         NaN       1   45745            0.0  13
# 4            3      379         NaN       1  161007            0.0  13
# 5            3      379         NaN       1   18787            0.0  16
# 6            3      379         NaN       1  103022            0.0  23
# 7            3      379         NaN       1  114221            0.0  19
# 8            3      379         NaN       1  165970            0.0  13
# 9           64      459         NaN       1   74544            0.0  22
# 10           3      379         NaN       1  172522            0.0  25
# 11           3      379         NaN       1  105861            0.0  13
# 12           3      379         NaN       1  210962            0.0  19
# 13           3      379         NaN       1  124979            0.0  18
# 14           3      379         NaN       1   38816            0.0  18
# 15           3      379         NaN       1   80447            0.0  19
# 16           3      379         NaN       1  134575            0.0  13
# 17           3      379         NaN       1   57576            0.0  19
# 18           3      379         NaN       1    7755            0.0  13
# 19           3      379         NaN       1   91749            0.0  19
# 20           3      379         NaN       1   50694            0.0  18
# 21           3      379         NaN       1  111385            0.0  18
# 22          14      478         NaN       1  125222            0.0   3
# 23           3      379         NaN       1  191759            0.0  13
# 24           3      379         NaN       1   53418            0.0  17
# 25           3      379         NaN       1  183168            0.0  19
# 26           3      379         NaN       1   47902            0.0  17
# 27           3      379         NaN       1  209663            0.0  13
# 28           3      379         NaN       1  129614            0.0  20
# 29           3      379         NaN       1  208347            0.0  19
# ...        ...      ...         ...     ...     ...            ...  ..
# 203694329   27      153  18790438.0       1   51432            NaN  13
# 203694330   14      401  18790440.0       1   14334            NaN  19
# 203694331    9      334  18790441.0       1   16749            NaN  13
# 203694332   23      153  18790442.0       1   17814            NaN  13
# 203694333   21      232  18790443.0       1    8825            NaN  13
# 203694334    8      259  18790444.0       2  115536            NaN  13
# 203694335    2      205  18790445.0       1  121472            NaN  19
# 203694336   12      242  18790446.0       1   38000            NaN  12
# 203694337    1      125  18790447.0       1   66176            NaN  19
# 203694338    2      205  18790448.0       1   25553            NaN  22
# 203694339   21      128  18790449.0       2  119531            NaN  19
# 203694340   13      469  18790450.0       1   14062            NaN  53
# 203694341   14      442  18790451.0       1   48536            NaN  19
# 203694342    1      125  18790452.0       1   93291            NaN  19
# 203694343    9      258  18790453.0       1   93291            NaN  19
# 203694344    1      125  18790455.0       1   55874            NaN  22
# 203694345    9      145  18790454.0       1   93291            NaN  19
# 203694346    8      259  18790456.0       1  100697            NaN  18
# 203694347   20      259  18790457.0       1   93291            NaN  19
# 203694348    2      452  18790458.0       1   85329            NaN  14
# 203694349   15      140  18790459.0       1  102467            NaN  17
# 203694350    9      445  18790460.0       1   80537            NaN  19
# 203694351    2      237  18790462.0       2  101214            NaN  16
# 203694352   17      128  18790461.0       1  113418            NaN  17
# 203694353   12      135  18790463.0       1   69245            NaN  13
# 203694354    9      127  18790464.0       1   99442            NaN  13
# 203694355   23      153  18790465.0       1   88046            NaN  37
# 203694356   18      265  18790467.0       1   81398            NaN  17
# 203694357   27      122  18790466.0       1  123236            NaN  13
# 203694358   12      265  18790468.0       2   73516            NaN  27
#
#            click_count_by_ip_os_device_dow  \
# 0                                      434
# 1                                      183
# 2                                       34
# 3                                     1501
# 4                                       28
# 5                                        1
# 6                                        1
# 7                                       51
# 8                                       19
# 9                                        5
# 10                                     109
# 11                                     495
# 12                                      84
# 13                                       1
# 14                                       1
# 15                                      42
# 16                                      16
# 17                                       1
# 18                                      34
# 19                                     100
# 20                                       9
# 21                                       4
# 22                                     123
# 23                                     407
# 24                                       6
# 25                                       3
# 26                                       6
# 27                                    2679
# 28                                      10
# 29                                      31
# ...                                    ...
# 203694329                               22
# 203694330                              274
# 203694331                               46
# 203694332                              260
# 203694333                               41
# 203694334                                4
# 203694335                             1789
# 203694336                                7
# 203694337                              304
# 203694338                              114
# 203694339                              878
# 203694340                                1
# 203694341                               80
# 203694342                             2245
# 203694343                             2245
# 203694344                               60
# 203694345                             2245
# 203694346                               17
# 203694347                             2245
# 203694348                               76
# 203694349                              173
# 203694350                               79
# 203694351                               13
# 203694352                               60
# 203694353                              100
# 203694354                                5
# 203694355                               23
# 203694356                               48
# 203694357                               13
# 203694358                              172
#
#            click_count_by_ip_os_device_dow_hour  click_count_by_ip  \
# 0                                             1              28085
# 1                                             1              26234
# 2                                             1              11002
# 3                                             1             188741
# 4                                             1               1171
# 5                                             1               4029
# 6                                             1               6099
# 7                                             1               2334
# 8                                             1               2014
# 9                                             1               3882
# 10                                            1               9494
# 11                                            1              12443
# 12                                            1               8688
# 13                                            1               1001
# 14                                            1               4551
# 15                                            1               5475
# 16                                            1               3267
# 17                                            1                297
# 18                                            1                685
# 19                                            1               6074
# 20                                            1               1221
# 21                                            1               2474
# 22                                            1             171961
# 23                                            1              25290
# 24                                            1               2572
# 25                                            1                 90
# 26                                            1               5766
# 27                                            1             173423
# 28                                            1               2201
# 29                                            1               2753
# ...                                         ...                ...
# 203694329                                     1                 22
# 203694330                                     1               2854
# 203694331                                     1               1528
# 203694332                                     1              11860
# 203694333                                     3               2273
# 203694334                                     1               1568
# 203694335                                     1              90013
# 203694336                                     1               1639
# 203694337                                     6              18979
# 203694338                                     1              49910
# 203694339                                     1             162916
# 203694340                                     1               4266
# 203694341                                     2               1748
# 203694342                                     7              38820
# 203694343                                     7              38820
# 203694344                                     6              13763
# 203694345                                     7              38820
# 203694346                                     1               3519
# 203694347                                     7              38820
# 203694348                                     2              75986
# 203694349                                     6              40051
# 203694350                                     6               1048
# 203694351                                     1              50215
# 203694352                                     2              13166
# 203694353                                     1               4666
# 203694354                                     2                377
# 203694355                                     1              11288
# 203694356                                     2              12192
# 203694357                                     1                963
# 203694358                                     1             839540
#
#                   ...           ip_device_countuniq  app_channel_countuniq  \
# 0                 ...                            26                     49
# 1                 ...                            22                     49
# 2                 ...                            16                     49
# 3                 ...                            99                     40
# 4                 ...                             5                     49
# 5                 ...                             2                     49
# 6                 ...                            11                     49
# 7                 ...                             4                     49
# 8                 ...                             6                     49
# 9                 ...                             6                      3
# 10                ...                            11                     49
# 11                ...                            29                     49
# 12                ...                            14                     49
# 13                ...                             4                     49
# 14                ...                             3                     49
# 15                ...                             4                     49
# 16                ...                             5                     49
# 17                ...                             1                     49
# 18                ...                             5                     49
# 19                ...                            11                     49
# 20                ...                             3                     49
# 21                ...                             9                     49
# 22                ...                           178                     40
# 23                ...                            37                     49
# 24                ...                             5                     49
# 25                ...                             2                     49
# 26                ...                            14                     49
# 27                ...                            50                     49
# 28                ...                             6                     49
# 29                ...                             6                     49
# ...               ...                           ...                    ...
# 203694329         ...                             1                      6
# 203694330         ...                             6                     40
# 203694331         ...                             5                     47
# 203694332         ...                            16                     11
# 203694333         ...                             9                      8
# 203694334         ...                             7                      4
# 203694335         ...                           124                     27
# 203694336         ...                             5                     33
# 203694337         ...                            12                     33
# 203694338         ...                            21                     27
# 203694339         ...                            93                      8
# 203694340         ...                             8                      9
# 203694341         ...                             7                     40
# 203694342         ...                            24                     33
# 203694343         ...                            24                     47
# 203694344         ...                            17                     33
# 203694345         ...                            24                     47
# 203694346         ...                             8                      4
# 203694347         ...                            24                      7
# 203694348         ...                           127                     27
# 203694349         ...                            38                     31
# 203694350         ...                             7                     47
# 203694351         ...                            95                     27
# 203694352         ...                            13                     11
# 203694353         ...                            10                     33
# 203694354         ...                             3                     47
# 203694355         ...                            16                     11
# 203694356         ...                            16                     20
# 203694357         ...                             4                      6
# 203694358         ...                           159                     33
#
#            ip_device_os_app_countuniq  ip_dow_hour_count  ip_app_count  \
# 0                                  49                  1          5759
# 1                                  48                  1          5245
# 2                                  41                  1          2156
# 3                                  58                  1         10547
# 4                                  28                  1           232
# 5                                  20                  1           884
# 6                                   4                  1          1256
# 7                                  29                  1           404
# 8                                  22                  1           434
# 9                                  18                  1            32
# 10                                 20                  1          1461
# 11                                 34                  1          1940
# 12                                 38                  1          1215
# 13                                 14                  1           165
# 14                                 26                  1           832
# 15                                 33                  1           892
# 16                                 25                  1           273
# 17                                 23                  1            47
# 18                                 23                  1           104
# 19                                 32                  1           911
# 20                                 18                  1           206
# 21                                 14                  1           457
# 22                                 33                  1          9398
# 23                                 38                  1          4534
# 24                                 25                  1           450
# 25                                  3                  1            16
# 26                                 23                  1          1014
# 27                                 49                  1         20297
# 28                                 16                  2           315
# 29                                 26                  1           225
# ...                               ...                ...           ...
# 203694329                          13                  1             1
# 203694330                          29                  1           184
# 203694331                          18                  1           144
# 203694332                          37                  1           248
# 203694333                          28                  3            58
# 203694334                           4                  1            20
# 203694335                          51                  2         11842
# 203694336                           7                  1           158
# 203694337                          42                  6           726
# 203694338                          36                  1         26695
# 203694339                          34                  1          5645
# 203694340                           7                  1           126
# 203694341                          29                  2           104
# 203694342                          37                  7           505
# 203694343                          37                  7          2366
# 203694344                          30                  6           542
# 203694345                          37                  7          2366
# 203694346                          23                  1           112
# 203694347                          37                  7           216
# 203694348                          31                  2         14959
# 203694349                          30                  6          3676
# 203694350                          23                  6           103
# 203694351                          18                  1          7207
# 203694352                          29                  2            55
# 203694353                          34                  1           647
# 203694354                          21                  2            35
# 203694355                          25                  1           224
# 203694356                          26                  2          1433
# 203694357                          23                  1             4
# 203694358                          28                  4        219988
#
#            ip_app_os_count  ip_dow_channel_var  ip_app_os_var  \
# 0                     1431            7.893333      36.597950
# 1                     1451            9.618462      25.959045
# 2                      462           15.600000      33.348476
# 3                     2186            5.947712      36.870251
# 4                       80           10.800000      37.221359
# 5                       30            2.333333      18.975863
# 6                        3            1.000000      44.333332
# 7                       88           32.000000      29.235109
# 8                       46            8.000000      26.908213
# 9                        1           13.809524            NaN
# 10                      34            7.873206      47.526737
# 11                     470            7.617168      45.830132
# 12                     325           16.333334      31.188187
# 13                       6           40.500000      15.466666
# 14                      27           12.666667      24.763533
# 15                     169           16.916666      35.519585
# 16                      70            2.000000      23.418013
# 17                      20                 NaN      11.734211
# 18                      16            1.333333      23.462500
# 19                     339           12.700000      29.937965
# 20                      15           40.500000      15.685715
# 21                       9           27.000000      35.277779
# 22                     152           10.685715      34.973465
# 23                    1105            8.079932      40.149372
# 24                      31           20.250000      48.655914
# 25                       3                 NaN      22.333334
# 26                      78                 NaN      36.947884
# 27                    3439            6.972166      38.278740
# 28                       6           12.600000      46.966667
# 29                      40           19.000000      23.419872
# ...                    ...                 ...            ...
# 203694329                1            1.333333            NaN
# 203694330               51           20.000000      29.783529
# 203694331               24           16.566668      37.389492
# 203694332               61           16.234848      39.937706
# 203694333               26            5.142857      34.038460
# 203694334                1            9.523809            NaN
# 203694335             2394           15.020443      28.733999
# 203694336                1                 NaN            NaN
# 203694337              175           12.250000      31.029755
# 203694338             1424           15.782972      47.541752
# 203694339             1135           12.102192      33.909885
# 203694340                1           19.361111            NaN
# 203694341               24           21.928572      37.471016
# 203694342              117            0.947619      36.501030
# 203694343              538            1.913846      28.743591
# 203694344               13           22.333334      40.474358
# 203694345              538           14.474748      28.743591
# 203694346               10           24.783333       1.655556
# 203694347               35           10.317524      32.294117
# 203694348              146           16.748381      31.969391
# 203694349              151            7.014452      49.619778
# 203694350               16           60.500000      18.600000
# 203694351               91           13.694435      25.020269
# 203694352                6           10.107617       0.300000
# 203694353              180           27.619047      36.789074
# 203694354               11           20.000000      35.363636
# 203694355               13           14.522223      23.358974
# 203694356               76           13.800467      21.325439
# 203694357                1           60.500000            NaN
# 203694358             1780           10.666474      35.386147
#
#            ip_app_channel_var  ip_app_channel_mean
# 0                    1.389350             8.521276
# 1                    1.103880             8.236263
# 2                    1.012026             8.872340
# 3                    1.070305            10.361702
# 4                    0.619048            11.428572
# 5                    1.937909            10.277778
# 6                    0.976950            11.208333
# 7                    2.028571             9.466666
# 8                    0.566667            14.333333
# 9                    0.555444            11.875000
# 10                   0.247768             9.843750
# 11                   2.183636            13.256757
# 12                   0.998851            11.133333
# 13                   2.266667             9.833333
# 14                   1.071225             8.888889
# 15                   1.031746             7.178571
# 16                   1.066667             9.500000
# 17                   5.333333             7.666667
# 18                   3.111111            12.000000
# 19                   1.719697            12.000000
# 20                   1.361111             8.333333
# 21                   1.670330             8.500000
# 22                   1.335227            10.969697
# 23                   0.656371            11.395349
# 24                   1.571429            10.933333
# 25                   0.500000            10.500000
# 26                   1.311111            10.611111
# 27                   0.357150             9.660378
# 28                   0.277778             9.777778
# 29                   2.285714            12.428572
# ...                       ...                  ...
# 203694329                 NaN            15.000000
# 203694330            1.596491            10.000000
# 203694331            0.692308            11.923077
# 203694332            1.137158             9.728745
# 203694333            1.065217            12.000000
# 203694334            0.500000            13.500000
# 203694335            1.148887            10.458585
# 203694336            2.000000            11.000000
# 203694337            1.734210            13.550000
# 203694338            1.153579            10.893300
# 203694339            0.698123            11.571559
# 203694340            1.418421            14.400000
# 203694341            1.839286             8.375000
# 203694342            0.562217            14.576923
# 203694343            0.489648            13.385715
# 203694344            0.893281            10.869565
# 203694345            0.628307            13.357142
# 203694346            1.391304            12.565217
# 203694347            0.435094            13.863095
# 203694348            1.185620            10.833962
# 203694349            1.066918            11.871875
# 203694350            2.000000             6.250000
# 203694351            0.529386             9.665807
# 203694352            0.208669            11.375000
# 203694353            0.361111             8.666667
# 203694354            0.000000             8.000000
# 203694355            1.207046            10.385651
# 203694356            0.000000            11.692307
# 203694357            0.500000             7.500000
# 203694358            1.060851            10.977614
#
# [203694359 rows x 37 columns]

# %%
# %%time
df.to_hdf("../data/merged_click_data.hdf", "merged_click_data")
# Out:
# CPU times: user 36.5 s, sys: 2min 56s, total: 3min 32s
# Wall time: 6min 16s

# %%
gc.collect()
# Out:
# 95

# %%
# %%time
df = pd.read_hdf("../data/merged_click_data.hdf", "merged_click_data")
# Out:
# CPU times: user 440 ms, sys: 12.6 s, total: 13 s
# Wall time: 36.5 s

# %%
df.dtypes
# Out:
# app                                              uint16
# channel                                          uint16
# click_id                                        float64
# device                                           uint16
# ip                                               uint32
# is_attributed                                   float64
# os                                               uint16
# click_count_by_ip_os_device_dow                  uint32
# click_count_by_ip_os_device_dow_hour             uint16
# click_count_by_ip                                uint32
# dow                                               uint8
# hour                                              uint8
# minute                                            uint8
# second                                            uint8
# rank_by_ip                                       uint32
# rank_by_ip_os_device                             uint32
# rank_by_ip_os_device_dow                         uint32
# click_time_interval_by_ip                       float64
# click_time_interval_by_ip_os_device             float64
# click_time_interval_by_ip_os_device_dow         float64
# click_time_interval_by_ip_os_device_dow_hour    float64
# ip_device_os_cumcount                            uint32
# ip_cumcount                                      uint32
# ip_channel_countuniq                              uint8
# ip_dow_hour_countuniq                             uint8
# ip_app_countuniq                                  uint8
# ip_app_os_countuniq                               uint8
# ip_device_countuniq                              uint16
# app_channel_countuniq                            uint32
# ip_device_os_app_countuniq                       uint32
# ip_dow_hour_count                                uint32
# ip_app_count                                     uint32
# ip_app_os_count                                  uint16
# ip_dow_channel_var                              float32
# ip_app_os_var                                   float32
# ip_app_channel_var                              float32
# ip_app_channel_mean                             float32
# dtype: object

# %%
# %%time
MOD = int(1e9+7)
df["ip_os_device_app_hash"] = (df["ip"].astype(str)+"_"+df["os"].astype(str)+"_"+df["device"].astype(str)+"_"+df["app"].astype(str)).apply(hash)%MOD
# Out:
# CPU times: user 11min 13s, sys: 1min 17s, total: 12min 31s
# Wall time: 12min 29s

# %%
df["ip_os_device_app_hash"] = df["ip_os_device_app_hash"].astype("uint32")

# %%
df.to_hdf("../data/merged_click_data.hdf", "merged_click_data")

# %% [markdown]
# # Add time difference features

# %%
df = pd.read_hdf("../data/merged_click_data.hdf", "merged_click_data")

# %%
df.dtypes
# Out:
# app                                              uint16
# channel                                          uint16
# click_id                                        float64
# device                                           uint16
# ip                                               uint32
# is_attributed                                   float64
# os                                               uint16
# click_count_by_ip_os_device_dow                  uint32
# click_count_by_ip_os_device_dow_hour             uint16
# click_count_by_ip                                uint32
# dow                                               uint8
# hour                                              uint8
# minute                                            uint8
# second                                            uint8
# rank_by_ip                                       uint32
# rank_by_ip_os_device                             uint32
# rank_by_ip_os_device_dow                         uint32
# click_time_interval_by_ip                       float64
# click_time_interval_by_ip_os_device             float64
# click_time_interval_by_ip_os_device_dow         float64
# click_time_interval_by_ip_os_device_dow_hour    float64
# ip_device_os_cumcount                            uint32
# ip_cumcount                                      uint32
# ip_channel_countuniq                              uint8
# ip_dow_hour_countuniq                             uint8
# ip_app_countuniq                                  uint8
# ip_app_os_countuniq                               uint8
# ip_device_countuniq                              uint16
# app_channel_countuniq                            uint32
# ip_device_os_app_countuniq                       uint32
# ip_dow_hour_count                                uint32
# ip_app_count                                     uint32
# ip_app_os_count                                  uint16
# ip_dow_channel_var                              float32
# ip_app_os_var                                   float32
# ip_app_channel_var                              float32
# ip_app_channel_mean                             float32
# ip_os_device_app_hash                            uint32
# dtype: object

# %%
df = df[["dow", "hour", "minute", "second", "ip_os_device_app_hash"]]

# %%
df["click_time_second"] = df["dow"].astype("uint32")*24*60*60 + df["hour"].astype("uint32")*60*60 + df["minute"].astype("uint32")*60 + df["second"].astype("uint32")

# %%
df
# Out:
#            dow  hour  minute  second  ip_os_device_app_hash  click_time_second
# 0            0    14      32      21              210218720              52341
# 1            0    14      33      34              808483042              52414
# 2            0    14      34      12              307460829              52452
# 3            0    14      34      52              250305947              52492
# 4            0    14      35       8              950166762              52508
# 5            0    14      36      26               90009919              52586
# 6            0    14      37      44              228641874              52664
# 7            0    14      37      59              261270055              52679
# 8            0    14      38      10              797366259              52690
# 9            0    14      38      23               87040044              52703
# 10           0    14      38      27              703373851              52707
# 11           0    14      38      51              421834599              52731
# 12           0    14      39      29               53350628              52769
# 13           0    14      40      16              525619396              52816
# 14           0    14      40      39              261686900              52839
# 15           0    14      40      51              148285333              52851
# 16           0    14      43      10              422766655              52990
# 17           0    14      43      14              414809083              52994
# 18           0    14      43      25              708420029              53005
# 19           0    14      43      51              801700946              53031
# 20           0    14      44       2              324757871              53042
# 21           0    14      44      15              856957796              53055
# 22           0    14      44      51              900600158              53091
# 23           0    14      44      51              728458752              53091
# 24           0    14      44      52              239525365              53092
# 25           0    14      47      49              103618493              53269
# 26           0    14      48       7              438668861              53287
# 27           0    14      48      55              646730421              53335
# 28           0    14      49      36              118748906              53376
# 29           0    14      49      38              805033446              53378
# ...        ...   ...     ...     ...                    ...                ...
# 203694329    4    15       0       0              752962404             399600
# 203694330    4    15       0       0              549313512             399600
# 203694331    4    15       0       0              548970373             399600
# 203694332    4    15       0       0              205155878             399600
# 203694333    4    15       0       0              801565914             399600
# 203694334    4    15       0       0              693863440             399600
# 203694335    4    15       0       0              688138810             399600
# 203694336    4    15       0       0              564527887             399600
# 203694337    4    15       0       0              839451070             399600
# 203694338    4    15       0       0              313201353             399600
# 203694339    4    15       0       0              157056077             399600
# 203694340    4    15       0       0              892919986             399600
# 203694341    4    15       0       0              894558563             399600
# 203694342    4    15       0       0                7706636             399600
# 203694343    4    15       0       0              278384507             399600
# 203694344    4    15       0       0              535988662             399600
# 203694345    4    15       0       0              278384507             399600
# 203694346    4    15       0       0              659787144             399600
# 203694347    4    15       0       0              809767354             399600
# 203694348    4    15       0       0              392208433             399600
# 203694349    4    15       0       0              581401198             399600
# 203694350    4    15       0       0              262478344             399600
# 203694351    4    15       0       0              228142379             399600
# 203694352    4    15       0       0               61770718             399600
# 203694353    4    15       0       0              989795271             399600
# 203694354    4    15       0       0              840793395             399600
# 203694355    4    15       0       0              648439816             399600
# 203694356    4    15       0       0              454367243             399600
# 203694357    4    15       0       0              122167087             399600
# 203694358    4    15       0       0              811829443             399600
#
# [203694359 rows x 6 columns]

# %%
# %%time
df.sort_values(by=["ip_os_device_app_hash", "click_time_second"], inplace=True)
# Out:
# CPU times: user 4min 26s, sys: 16.6 s, total: 4min 43s
# Wall time: 4min 43s

# %%
df
# Out:
#            dow  hour  minute  second  ip_os_device_app_hash  click_time_second
# 5983865      0    22      18       1                    111              80281
# 20255942     1     3      17      36                    111              98256
# 28230899     1     5      37      16                    111             106636
# 32910114     1     7      12       4                    111             112324
# 61244089     1    16      35      51                    111             146151
# 64804845     1    20      43      33                    111             161013
# 71205361     2     0      38      39                    111             175119
# 73762271     2     1      24      26                    111             177866
# 100583594    2     9      49      39                    111             208179
# 104020559    2    10      50      55                    111             211855
# 119066855    2    15       5       8                    111             227108
# 10683421     1     0      23      22                    156              87802
# 10816085     1     0      25      30                    156              87930
# 31655690     1     6      45      50                    156             110750
# 177130874    3    13      37      31                    196             308251
# 198427746    4    13      23      13                    196             393793
# 54789725     1    14      20       8                    218             138008
# 55543710     1    14      34      18                    237             138858
# 77985561     2     2      42      26                    237             182546
# 120265428    2    15      24      13                    237             228253
# 121983682    2    15      58       2                    237             230282
# 75021437     2     1      50       8                    254             179408
# 80671228     2     3      29      56                    254             185396
# 80671262     2     3      29      56                    254             185396
# 116017177    2    14      15       9                    254             224109
# 116794849    2    14      27      55                    254             224875
# 14016959     1     1      19      28                    262              91168
# 107443013    2    11      51      10                    367             215470
# 184064789    3    15      41      30                    388             315690
# 69134368     2     0       3      28                    401             173008
# ...        ...   ...     ...     ...                    ...                ...
# 35811637     1     8      11      17              999999770             115877
# 200299711    4    13      57      40              999999770             395860
# 171304442    3    11      54      30              999999773             302070
# 115385788    2    14       5       1              999999782             223501
# 117263532    2    14      35      43              999999782             225343
# 147660106    3     4      44      16              999999844             276256
# 154097689    3     6      28       4              999999844             282484
# 164612862    3     9      53      26              999999844             294806
# 164716103    3     9      55      21              999999844             294921
# 164734205    3     9      55      41              999999844             294941
# 184094199    3    15      42       8              999999844             315728
# 184181484    3    15      43      56              999999844             315836
# 184184258    3    15      43      59              999999844             315839
# 76251593     2     2      14       8              999999900             180848
# 76251759     2     2      14       8              999999900             180848
# 80239597     2     3      21      27              999999900             184887
# 91344922     2     6      47      45              999999900             197265
# 100261915    2     9      43      25              999999900             207805
# 100352995    2     9      45      10              999999900             207910
# 104891289    2    11       6      37              999999900             212797
# 115208879    2    14       2       8              999999900             223328
# 191329609    4     9       4      12              999999900             378252
# 194513437    4    10       8       7              999999900             382087
# 5504004      0    21      37      14              999999976              77834
# 120860410    2    15      35      18              999999976             228918
# 128821360    2    22      32      58              999999976             253978
# 185493020    4     4      10      28              999999976             360628
# 185669692    4     4      13      31              999999976             360811
# 185682216    4     4      13      44              999999976             360824
# 195825851    4    10      33      25              999999978             383605
#
# [203694359 rows x 6 columns]

# %%
df["click_time_shift"] = df["click_time_second"].shift()

# %%
df["click_time_interval_ip_device_os_app_hash"] = df["click_time_second"] - df["click_time_shift"]

# %%
df["ip_os_device_app_hash_shift"] = df["ip_os_device_app_hash"].shift()

# %%
# %%time
df["click_time_interval_ip_device_os_app_hash"].where(df["ip_os_device_app_hash"]==df["ip_os_device_app_hash_shift"], np.nan, inplace=True)
# Out:
# CPU times: user 1.84 s, sys: 644 ms, total: 2.48 s
# Wall time: 2.48 s

# %%
df
# Out:
#            dow  hour  minute  second  ip_os_device_app_hash  \
# 5983865      0    22      18       1                    111
# 20255942     1     3      17      36                    111
# 28230899     1     5      37      16                    111
# 32910114     1     7      12       4                    111
# 61244089     1    16      35      51                    111
# 64804845     1    20      43      33                    111
# 71205361     2     0      38      39                    111
# 73762271     2     1      24      26                    111
# 100583594    2     9      49      39                    111
# 104020559    2    10      50      55                    111
# 119066855    2    15       5       8                    111
# 10683421     1     0      23      22                    156
# 10816085     1     0      25      30                    156
# 31655690     1     6      45      50                    156
# 177130874    3    13      37      31                    196
# 198427746    4    13      23      13                    196
# 54789725     1    14      20       8                    218
# 55543710     1    14      34      18                    237
# 77985561     2     2      42      26                    237
# 120265428    2    15      24      13                    237
# 121983682    2    15      58       2                    237
# 75021437     2     1      50       8                    254
# 80671228     2     3      29      56                    254
# 80671262     2     3      29      56                    254
# 116017177    2    14      15       9                    254
# 116794849    2    14      27      55                    254
# 14016959     1     1      19      28                    262
# 107443013    2    11      51      10                    367
# 184064789    3    15      41      30                    388
# 69134368     2     0       3      28                    401
# ...        ...   ...     ...     ...                    ...
# 35811637     1     8      11      17              999999770
# 200299711    4    13      57      40              999999770
# 171304442    3    11      54      30              999999773
# 115385788    2    14       5       1              999999782
# 117263532    2    14      35      43              999999782
# 147660106    3     4      44      16              999999844
# 154097689    3     6      28       4              999999844
# 164612862    3     9      53      26              999999844
# 164716103    3     9      55      21              999999844
# 164734205    3     9      55      41              999999844
# 184094199    3    15      42       8              999999844
# 184181484    3    15      43      56              999999844
# 184184258    3    15      43      59              999999844
# 76251593     2     2      14       8              999999900
# 76251759     2     2      14       8              999999900
# 80239597     2     3      21      27              999999900
# 91344922     2     6      47      45              999999900
# 100261915    2     9      43      25              999999900
# 100352995    2     9      45      10              999999900
# 104891289    2    11       6      37              999999900
# 115208879    2    14       2       8              999999900
# 191329609    4     9       4      12              999999900
# 194513437    4    10       8       7              999999900
# 5504004      0    21      37      14              999999976
# 120860410    2    15      35      18              999999976
# 128821360    2    22      32      58              999999976
# 185493020    4     4      10      28              999999976
# 185669692    4     4      13      31              999999976
# 185682216    4     4      13      44              999999976
# 195825851    4    10      33      25              999999978
#
#            click_time_second  click_time_shift  ip_os_device_app_hash_shift  \
# 5983865                80281               NaN                          NaN
# 20255942               98256           80281.0                        111.0
# 28230899              106636           98256.0                        111.0
# 32910114              112324          106636.0                        111.0
# 61244089              146151          112324.0                        111.0
# 64804845              161013          146151.0                        111.0
# 71205361              175119          161013.0                        111.0
# 73762271              177866          175119.0                        111.0
# 100583594             208179          177866.0                        111.0
# 104020559             211855          208179.0                        111.0
# 119066855             227108          211855.0                        111.0
# 10683421               87802          227108.0                        111.0
# 10816085               87930           87802.0                        156.0
# 31655690              110750           87930.0                        156.0
# 177130874             308251          110750.0                        156.0
# 198427746             393793          308251.0                        196.0
# 54789725              138008          393793.0                        196.0
# 55543710              138858          138008.0                        218.0
# 77985561              182546          138858.0                        237.0
# 120265428             228253          182546.0                        237.0
# 121983682             230282          228253.0                        237.0
# 75021437              179408          230282.0                        237.0
# 80671228              185396          179408.0                        254.0
# 80671262              185396          185396.0                        254.0
# 116017177             224109          185396.0                        254.0
# 116794849             224875          224109.0                        254.0
# 14016959               91168          224875.0                        254.0
# 107443013             215470           91168.0                        262.0
# 184064789             315690          215470.0                        367.0
# 69134368              173008          315690.0                        388.0
# ...                      ...               ...                          ...
# 35811637              115877          227321.0                  999999764.0
# 200299711             395860          115877.0                  999999770.0
# 171304442             302070          395860.0                  999999770.0
# 115385788             223501          302070.0                  999999773.0
# 117263532             225343          223501.0                  999999782.0
# 147660106             276256          225343.0                  999999782.0
# 154097689             282484          276256.0                  999999844.0
# 164612862             294806          282484.0                  999999844.0
# 164716103             294921          294806.0                  999999844.0
# 164734205             294941          294921.0                  999999844.0
# 184094199             315728          294941.0                  999999844.0
# 184181484             315836          315728.0                  999999844.0
# 184184258             315839          315836.0                  999999844.0
# 76251593              180848          315839.0                  999999844.0
# 76251759              180848          180848.0                  999999900.0
# 80239597              184887          180848.0                  999999900.0
# 91344922              197265          184887.0                  999999900.0
# 100261915             207805          197265.0                  999999900.0
# 100352995             207910          207805.0                  999999900.0
# 104891289             212797          207910.0                  999999900.0
# 115208879             223328          212797.0                  999999900.0
# 191329609             378252          223328.0                  999999900.0
# 194513437             382087          378252.0                  999999900.0
# 5504004                77834          382087.0                  999999900.0
# 120860410             228918           77834.0                  999999976.0
# 128821360             253978          228918.0                  999999976.0
# 185493020             360628          253978.0                  999999976.0
# 185669692             360811          360628.0                  999999976.0
# 185682216             360824          360811.0                  999999976.0
# 195825851             383605          360824.0                  999999976.0
#
#            click_time_interval_ip_device_os_app_hash
# 5983865                                          NaN
# 20255942                                     17975.0
# 28230899                                      8380.0
# 32910114                                      5688.0
# 61244089                                     33827.0
# 64804845                                     14862.0
# 71205361                                     14106.0
# 73762271                                      2747.0
# 100583594                                    30313.0
# 104020559                                     3676.0
# 119066855                                    15253.0
# 10683421                                         NaN
# 10816085                                       128.0
# 31655690                                     22820.0
# 177130874                                        NaN
# 198427746                                    85542.0
# 54789725                                         NaN
# 55543710                                         NaN
# 77985561                                     43688.0
# 120265428                                    45707.0
# 121983682                                     2029.0
# 75021437                                         NaN
# 80671228                                      5988.0
# 80671262                                         0.0
# 116017177                                    38713.0
# 116794849                                      766.0
# 14016959                                         NaN
# 107443013                                        NaN
# 184064789                                        NaN
# 69134368                                         NaN
# ...                                              ...
# 35811637                                         NaN
# 200299711                                   279983.0
# 171304442                                        NaN
# 115385788                                        NaN
# 117263532                                     1842.0
# 147660106                                        NaN
# 154097689                                     6228.0
# 164612862                                    12322.0
# 164716103                                      115.0
# 164734205                                       20.0
# 184094199                                    20787.0
# 184181484                                      108.0
# 184184258                                        3.0
# 76251593                                         NaN
# 76251759                                         0.0
# 80239597                                      4039.0
# 91344922                                     12378.0
# 100261915                                    10540.0
# 100352995                                      105.0
# 104891289                                     4887.0
# 115208879                                    10531.0
# 191329609                                   154924.0
# 194513437                                     3835.0
# 5504004                                          NaN
# 120860410                                   151084.0
# 128821360                                    25060.0
# 185493020                                   106650.0
# 185669692                                      183.0
# 185682216                                       13.0
# 195825851                                        NaN
#
# [203694359 rows x 9 columns]

# %%
df["first_click_interval_ip_device_os_app_hash"] = df["click_time_interval_ip_device_os_app_hash"].isnull()

# %%
df
# Out:
#            dow  hour  minute  second  ip_os_device_app_hash  \
# 5983865      0    22      18       1                    111
# 20255942     1     3      17      36                    111
# 28230899     1     5      37      16                    111
# 32910114     1     7      12       4                    111
# 61244089     1    16      35      51                    111
# 64804845     1    20      43      33                    111
# 71205361     2     0      38      39                    111
# 73762271     2     1      24      26                    111
# 100583594    2     9      49      39                    111
# 104020559    2    10      50      55                    111
# 119066855    2    15       5       8                    111
# 10683421     1     0      23      22                    156
# 10816085     1     0      25      30                    156
# 31655690     1     6      45      50                    156
# 177130874    3    13      37      31                    196
# 198427746    4    13      23      13                    196
# 54789725     1    14      20       8                    218
# 55543710     1    14      34      18                    237
# 77985561     2     2      42      26                    237
# 120265428    2    15      24      13                    237
# 121983682    2    15      58       2                    237
# 75021437     2     1      50       8                    254
# 80671228     2     3      29      56                    254
# 80671262     2     3      29      56                    254
# 116017177    2    14      15       9                    254
# 116794849    2    14      27      55                    254
# 14016959     1     1      19      28                    262
# 107443013    2    11      51      10                    367
# 184064789    3    15      41      30                    388
# 69134368     2     0       3      28                    401
# ...        ...   ...     ...     ...                    ...
# 35811637     1     8      11      17              999999770
# 200299711    4    13      57      40              999999770
# 171304442    3    11      54      30              999999773
# 115385788    2    14       5       1              999999782
# 117263532    2    14      35      43              999999782
# 147660106    3     4      44      16              999999844
# 154097689    3     6      28       4              999999844
# 164612862    3     9      53      26              999999844
# 164716103    3     9      55      21              999999844
# 164734205    3     9      55      41              999999844
# 184094199    3    15      42       8              999999844
# 184181484    3    15      43      56              999999844
# 184184258    3    15      43      59              999999844
# 76251593     2     2      14       8              999999900
# 76251759     2     2      14       8              999999900
# 80239597     2     3      21      27              999999900
# 91344922     2     6      47      45              999999900
# 100261915    2     9      43      25              999999900
# 100352995    2     9      45      10              999999900
# 104891289    2    11       6      37              999999900
# 115208879    2    14       2       8              999999900
# 191329609    4     9       4      12              999999900
# 194513437    4    10       8       7              999999900
# 5504004      0    21      37      14              999999976
# 120860410    2    15      35      18              999999976
# 128821360    2    22      32      58              999999976
# 185493020    4     4      10      28              999999976
# 185669692    4     4      13      31              999999976
# 185682216    4     4      13      44              999999976
# 195825851    4    10      33      25              999999978
#
#            click_time_second  click_time_shift  ip_os_device_app_hash_shift  \
# 5983865                80281               NaN                          NaN
# 20255942               98256           80281.0                        111.0
# 28230899              106636           98256.0                        111.0
# 32910114              112324          106636.0                        111.0
# 61244089              146151          112324.0                        111.0
# 64804845              161013          146151.0                        111.0
# 71205361              175119          161013.0                        111.0
# 73762271              177866          175119.0                        111.0
# 100583594             208179          177866.0                        111.0
# 104020559             211855          208179.0                        111.0
# 119066855             227108          211855.0                        111.0
# 10683421               87802          227108.0                        111.0
# 10816085               87930           87802.0                        156.0
# 31655690              110750           87930.0                        156.0
# 177130874             308251          110750.0                        156.0
# 198427746             393793          308251.0                        196.0
# 54789725              138008          393793.0                        196.0
# 55543710              138858          138008.0                        218.0
# 77985561              182546          138858.0                        237.0
# 120265428             228253          182546.0                        237.0
# 121983682             230282          228253.0                        237.0
# 75021437              179408          230282.0                        237.0
# 80671228              185396          179408.0                        254.0
# 80671262              185396          185396.0                        254.0
# 116017177             224109          185396.0                        254.0
# 116794849             224875          224109.0                        254.0
# 14016959               91168          224875.0                        254.0
# 107443013             215470           91168.0                        262.0
# 184064789             315690          215470.0                        367.0
# 69134368              173008          315690.0                        388.0
# ...                      ...               ...                          ...
# 35811637              115877          227321.0                  999999764.0
# 200299711             395860          115877.0                  999999770.0
# 171304442             302070          395860.0                  999999770.0
# 115385788             223501          302070.0                  999999773.0
# 117263532             225343          223501.0                  999999782.0
# 147660106             276256          225343.0                  999999782.0
# 154097689             282484          276256.0                  999999844.0
# 164612862             294806          282484.0                  999999844.0
# 164716103             294921          294806.0                  999999844.0
# 164734205             294941          294921.0                  999999844.0
# 184094199             315728          294941.0                  999999844.0
# 184181484             315836          315728.0                  999999844.0
# 184184258             315839          315836.0                  999999844.0
# 76251593              180848          315839.0                  999999844.0
# 76251759              180848          180848.0                  999999900.0
# 80239597              184887          180848.0                  999999900.0
# 91344922              197265          184887.0                  999999900.0
# 100261915             207805          197265.0                  999999900.0
# 100352995             207910          207805.0                  999999900.0
# 104891289             212797          207910.0                  999999900.0
# 115208879             223328          212797.0                  999999900.0
# 191329609             378252          223328.0                  999999900.0
# 194513437             382087          378252.0                  999999900.0
# 5504004                77834          382087.0                  999999900.0
# 120860410             228918           77834.0                  999999976.0
# 128821360             253978          228918.0                  999999976.0
# 185493020             360628          253978.0                  999999976.0
# 185669692             360811          360628.0                  999999976.0
# 185682216             360824          360811.0                  999999976.0
# 195825851             383605          360824.0                  999999976.0
#
#            click_time_interval_ip_device_os_app_hash  \
# 5983865                                          NaN
# 20255942                                     17975.0
# 28230899                                      8380.0
# 32910114                                      5688.0
# 61244089                                     33827.0
# 64804845                                     14862.0
# 71205361                                     14106.0
# 73762271                                      2747.0
# 100583594                                    30313.0
# 104020559                                     3676.0
# 119066855                                    15253.0
# 10683421                                         NaN
# 10816085                                       128.0
# 31655690                                     22820.0
# 177130874                                        NaN
# 198427746                                    85542.0
# 54789725                                         NaN
# 55543710                                         NaN
# 77985561                                     43688.0
# 120265428                                    45707.0
# 121983682                                     2029.0
# 75021437                                         NaN
# 80671228                                      5988.0
# 80671262                                         0.0
# 116017177                                    38713.0
# 116794849                                      766.0
# 14016959                                         NaN
# 107443013                                        NaN
# 184064789                                        NaN
# 69134368                                         NaN
# ...                                              ...
# 35811637                                         NaN
# 200299711                                   279983.0
# 171304442                                        NaN
# 115385788                                        NaN
# 117263532                                     1842.0
# 147660106                                        NaN
# 154097689                                     6228.0
# 164612862                                    12322.0
# 164716103                                      115.0
# 164734205                                       20.0
# 184094199                                    20787.0
# 184181484                                      108.0
# 184184258                                        3.0
# 76251593                                         NaN
# 76251759                                         0.0
# 80239597                                      4039.0
# 91344922                                     12378.0
# 100261915                                    10540.0
# 100352995                                      105.0
# 104891289                                     4887.0
# 115208879                                    10531.0
# 191329609                                   154924.0
# 194513437                                     3835.0
# 5504004                                          NaN
# 120860410                                   151084.0
# 128821360                                    25060.0
# 185493020                                   106650.0
# 185669692                                      183.0
# 185682216                                       13.0
# 195825851                                        NaN
#
#            first_click_interval_ip_device_os_app_hash
# 5983865                                          True
# 20255942                                        False
# 28230899                                        False
# 32910114                                        False
# 61244089                                        False
# 64804845                                        False
# 71205361                                        False
# 73762271                                        False
# 100583594                                       False
# 104020559                                       False
# 119066855                                       False
# 10683421                                         True
# 10816085                                        False
# 31655690                                        False
# 177130874                                        True
# 198427746                                       False
# 54789725                                         True
# 55543710                                         True
# 77985561                                        False
# 120265428                                       False
# 121983682                                       False
# 75021437                                         True
# 80671228                                        False
# 80671262                                        False
# 116017177                                       False
# 116794849                                       False
# 14016959                                         True
# 107443013                                        True
# 184064789                                        True
# 69134368                                         True
# ...                                               ...
# 35811637                                         True
# 200299711                                       False
# 171304442                                        True
# 115385788                                        True
# 117263532                                       False
# 147660106                                        True
# 154097689                                       False
# 164612862                                       False
# 164716103                                       False
# 164734205                                       False
# 184094199                                       False
# 184181484                                       False
# 184184258                                       False
# 76251593                                         True
# 76251759                                        False
# 80239597                                        False
# 91344922                                        False
# 100261915                                       False
# 100352995                                       False
# 104891289                                       False
# 115208879                                       False
# 191329609                                       False
# 194513437                                       False
# 5504004                                          True
# 120860410                                       False
# 128821360                                       False
# 185493020                                       False
# 185669692                                       False
# 185682216                                       False
# 195825851                                        True
#
# [203694359 rows x 10 columns]

# %%
df.drop(columns=["ip_os_device_app_hash_shift", "click_time_shift"], inplace=True)

# %%
df
# Out:
#            dow  hour  minute  second  ip_os_device_app_hash  \
# 5983865      0    22      18       1                    111
# 20255942     1     3      17      36                    111
# 28230899     1     5      37      16                    111
# 32910114     1     7      12       4                    111
# 61244089     1    16      35      51                    111
# 64804845     1    20      43      33                    111
# 71205361     2     0      38      39                    111
# 73762271     2     1      24      26                    111
# 100583594    2     9      49      39                    111
# 104020559    2    10      50      55                    111
# 119066855    2    15       5       8                    111
# 10683421     1     0      23      22                    156
# 10816085     1     0      25      30                    156
# 31655690     1     6      45      50                    156
# 177130874    3    13      37      31                    196
# 198427746    4    13      23      13                    196
# 54789725     1    14      20       8                    218
# 55543710     1    14      34      18                    237
# 77985561     2     2      42      26                    237
# 120265428    2    15      24      13                    237
# 121983682    2    15      58       2                    237
# 75021437     2     1      50       8                    254
# 80671228     2     3      29      56                    254
# 80671262     2     3      29      56                    254
# 116017177    2    14      15       9                    254
# 116794849    2    14      27      55                    254
# 14016959     1     1      19      28                    262
# 107443013    2    11      51      10                    367
# 184064789    3    15      41      30                    388
# 69134368     2     0       3      28                    401
# ...        ...   ...     ...     ...                    ...
# 35811637     1     8      11      17              999999770
# 200299711    4    13      57      40              999999770
# 171304442    3    11      54      30              999999773
# 115385788    2    14       5       1              999999782
# 117263532    2    14      35      43              999999782
# 147660106    3     4      44      16              999999844
# 154097689    3     6      28       4              999999844
# 164612862    3     9      53      26              999999844
# 164716103    3     9      55      21              999999844
# 164734205    3     9      55      41              999999844
# 184094199    3    15      42       8              999999844
# 184181484    3    15      43      56              999999844
# 184184258    3    15      43      59              999999844
# 76251593     2     2      14       8              999999900
# 76251759     2     2      14       8              999999900
# 80239597     2     3      21      27              999999900
# 91344922     2     6      47      45              999999900
# 100261915    2     9      43      25              999999900
# 100352995    2     9      45      10              999999900
# 104891289    2    11       6      37              999999900
# 115208879    2    14       2       8              999999900
# 191329609    4     9       4      12              999999900
# 194513437    4    10       8       7              999999900
# 5504004      0    21      37      14              999999976
# 120860410    2    15      35      18              999999976
# 128821360    2    22      32      58              999999976
# 185493020    4     4      10      28              999999976
# 185669692    4     4      13      31              999999976
# 185682216    4     4      13      44              999999976
# 195825851    4    10      33      25              999999978
#
#            click_time_second  click_time_interval_ip_device_os_app_hash  \
# 5983865                80281                                        NaN
# 20255942               98256                                    17975.0
# 28230899              106636                                     8380.0
# 32910114              112324                                     5688.0
# 61244089              146151                                    33827.0
# 64804845              161013                                    14862.0
# 71205361              175119                                    14106.0
# 73762271              177866                                     2747.0
# 100583594             208179                                    30313.0
# 104020559             211855                                     3676.0
# 119066855             227108                                    15253.0
# 10683421               87802                                        NaN
# 10816085               87930                                      128.0
# 31655690              110750                                    22820.0
# 177130874             308251                                        NaN
# 198427746             393793                                    85542.0
# 54789725              138008                                        NaN
# 55543710              138858                                        NaN
# 77985561              182546                                    43688.0
# 120265428             228253                                    45707.0
# 121983682             230282                                     2029.0
# 75021437              179408                                        NaN
# 80671228              185396                                     5988.0
# 80671262              185396                                        0.0
# 116017177             224109                                    38713.0
# 116794849             224875                                      766.0
# 14016959               91168                                        NaN
# 107443013             215470                                        NaN
# 184064789             315690                                        NaN
# 69134368              173008                                        NaN
# ...                      ...                                        ...
# 35811637              115877                                        NaN
# 200299711             395860                                   279983.0
# 171304442             302070                                        NaN
# 115385788             223501                                        NaN
# 117263532             225343                                     1842.0
# 147660106             276256                                        NaN
# 154097689             282484                                     6228.0
# 164612862             294806                                    12322.0
# 164716103             294921                                      115.0
# 164734205             294941                                       20.0
# 184094199             315728                                    20787.0
# 184181484             315836                                      108.0
# 184184258             315839                                        3.0
# 76251593              180848                                        NaN
# 76251759              180848                                        0.0
# 80239597              184887                                     4039.0
# 91344922              197265                                    12378.0
# 100261915             207805                                    10540.0
# 100352995             207910                                      105.0
# 104891289             212797                                     4887.0
# 115208879             223328                                    10531.0
# 191329609             378252                                   154924.0
# 194513437             382087                                     3835.0
# 5504004                77834                                        NaN
# 120860410             228918                                   151084.0
# 128821360             253978                                    25060.0
# 185493020             360628                                   106650.0
# 185669692             360811                                      183.0
# 185682216             360824                                       13.0
# 195825851             383605                                        NaN
#
#            first_click_interval_ip_device_os_app_hash
# 5983865                                          True
# 20255942                                        False
# 28230899                                        False
# 32910114                                        False
# 61244089                                        False
# 64804845                                        False
# 71205361                                        False
# 73762271                                        False
# 100583594                                       False
# 104020559                                       False
# 119066855                                       False
# 10683421                                         True
# 10816085                                        False
# 31655690                                        False
# 177130874                                        True
# 198427746                                       False
# 54789725                                         True
# 55543710                                         True
# 77985561                                        False
# 120265428                                       False
# 121983682                                       False
# 75021437                                         True
# 80671228                                        False
# 80671262                                        False
# 116017177                                       False
# 116794849                                       False
# 14016959                                         True
# 107443013                                        True
# 184064789                                        True
# 69134368                                         True
# ...                                               ...
# 35811637                                         True
# 200299711                                       False
# 171304442                                        True
# 115385788                                        True
# 117263532                                       False
# 147660106                                        True
# 154097689                                       False
# 164612862                                       False
# 164716103                                       False
# 164734205                                       False
# 184094199                                       False
# 184181484                                       False
# 184184258                                       False
# 76251593                                         True
# 76251759                                        False
# 80239597                                        False
# 91344922                                        False
# 100261915                                       False
# 100352995                                       False
# 104891289                                       False
# 115208879                                       False
# 191329609                                       False
# 194513437                                       False
# 5504004                                          True
# 120860410                                       False
# 128821360                                       False
# 185493020                                       False
# 185669692                                       False
# 185682216                                       False
# 195825851                                        True
#
# [203694359 rows x 8 columns]

# %%
df["click_time_interval_ip_device_os_app_hash"].max()
# Out:
# 341856.0

# %%
df["click_time_interval_ip_device_os_app_hash"].fillna(1e9+7, inplace=True)

# %%
df["click_time_interval_ip_device_os_app_hash"] = df["click_time_interval_ip_device_os_app_hash"].astype("uint32")

# %%
df
# Out:
#            dow  hour  minute  second  ip_os_device_app_hash  \
# 5983865      0    22      18       1                    111
# 20255942     1     3      17      36                    111
# 28230899     1     5      37      16                    111
# 32910114     1     7      12       4                    111
# 61244089     1    16      35      51                    111
# 64804845     1    20      43      33                    111
# 71205361     2     0      38      39                    111
# 73762271     2     1      24      26                    111
# 100583594    2     9      49      39                    111
# 104020559    2    10      50      55                    111
# 119066855    2    15       5       8                    111
# 10683421     1     0      23      22                    156
# 10816085     1     0      25      30                    156
# 31655690     1     6      45      50                    156
# 177130874    3    13      37      31                    196
# 198427746    4    13      23      13                    196
# 54789725     1    14      20       8                    218
# 55543710     1    14      34      18                    237
# 77985561     2     2      42      26                    237
# 120265428    2    15      24      13                    237
# 121983682    2    15      58       2                    237
# 75021437     2     1      50       8                    254
# 80671228     2     3      29      56                    254
# 80671262     2     3      29      56                    254
# 116017177    2    14      15       9                    254
# 116794849    2    14      27      55                    254
# 14016959     1     1      19      28                    262
# 107443013    2    11      51      10                    367
# 184064789    3    15      41      30                    388
# 69134368     2     0       3      28                    401
# ...        ...   ...     ...     ...                    ...
# 35811637     1     8      11      17              999999770
# 200299711    4    13      57      40              999999770
# 171304442    3    11      54      30              999999773
# 115385788    2    14       5       1              999999782
# 117263532    2    14      35      43              999999782
# 147660106    3     4      44      16              999999844
# 154097689    3     6      28       4              999999844
# 164612862    3     9      53      26              999999844
# 164716103    3     9      55      21              999999844
# 164734205    3     9      55      41              999999844
# 184094199    3    15      42       8              999999844
# 184181484    3    15      43      56              999999844
# 184184258    3    15      43      59              999999844
# 76251593     2     2      14       8              999999900
# 76251759     2     2      14       8              999999900
# 80239597     2     3      21      27              999999900
# 91344922     2     6      47      45              999999900
# 100261915    2     9      43      25              999999900
# 100352995    2     9      45      10              999999900
# 104891289    2    11       6      37              999999900
# 115208879    2    14       2       8              999999900
# 191329609    4     9       4      12              999999900
# 194513437    4    10       8       7              999999900
# 5504004      0    21      37      14              999999976
# 120860410    2    15      35      18              999999976
# 128821360    2    22      32      58              999999976
# 185493020    4     4      10      28              999999976
# 185669692    4     4      13      31              999999976
# 185682216    4     4      13      44              999999976
# 195825851    4    10      33      25              999999978
#
#            click_time_second  click_time_interval_ip_device_os_app_hash  \
# 5983865                80281                                 1000000007
# 20255942               98256                                      17975
# 28230899              106636                                       8380
# 32910114              112324                                       5688
# 61244089              146151                                      33827
# 64804845              161013                                      14862
# 71205361              175119                                      14106
# 73762271              177866                                       2747
# 100583594             208179                                      30313
# 104020559             211855                                       3676
# 119066855             227108                                      15253
# 10683421               87802                                 1000000007
# 10816085               87930                                        128
# 31655690              110750                                      22820
# 177130874             308251                                 1000000007
# 198427746             393793                                      85542
# 54789725              138008                                 1000000007
# 55543710              138858                                 1000000007
# 77985561              182546                                      43688
# 120265428             228253                                      45707
# 121983682             230282                                       2029
# 75021437              179408                                 1000000007
# 80671228              185396                                       5988
# 80671262              185396                                          0
# 116017177             224109                                      38713
# 116794849             224875                                        766
# 14016959               91168                                 1000000007
# 107443013             215470                                 1000000007
# 184064789             315690                                 1000000007
# 69134368              173008                                 1000000007
# ...                      ...                                        ...
# 35811637              115877                                 1000000007
# 200299711             395860                                     279983
# 171304442             302070                                 1000000007
# 115385788             223501                                 1000000007
# 117263532             225343                                       1842
# 147660106             276256                                 1000000007
# 154097689             282484                                       6228
# 164612862             294806                                      12322
# 164716103             294921                                        115
# 164734205             294941                                         20
# 184094199             315728                                      20787
# 184181484             315836                                        108
# 184184258             315839                                          3
# 76251593              180848                                 1000000007
# 76251759              180848                                          0
# 80239597              184887                                       4039
# 91344922              197265                                      12378
# 100261915             207805                                      10540
# 100352995             207910                                        105
# 104891289             212797                                       4887
# 115208879             223328                                      10531
# 191329609             378252                                     154924
# 194513437             382087                                       3835
# 5504004                77834                                 1000000007
# 120860410             228918                                     151084
# 128821360             253978                                      25060
# 185493020             360628                                     106650
# 185669692             360811                                        183
# 185682216             360824                                         13
# 195825851             383605                                 1000000007
#
#            first_click_interval_ip_device_os_app_hash
# 5983865                                          True
# 20255942                                        False
# 28230899                                        False
# 32910114                                        False
# 61244089                                        False
# 64804845                                        False
# 71205361                                        False
# 73762271                                        False
# 100583594                                       False
# 104020559                                       False
# 119066855                                       False
# 10683421                                         True
# 10816085                                        False
# 31655690                                        False
# 177130874                                        True
# 198427746                                       False
# 54789725                                         True
# 55543710                                         True
# 77985561                                        False
# 120265428                                       False
# 121983682                                       False
# 75021437                                         True
# 80671228                                        False
# 80671262                                        False
# 116017177                                       False
# 116794849                                       False
# 14016959                                         True
# 107443013                                        True
# 184064789                                        True
# 69134368                                         True
# ...                                               ...
# 35811637                                         True
# 200299711                                       False
# 171304442                                        True
# 115385788                                        True
# 117263532                                       False
# 147660106                                        True
# 154097689                                       False
# 164612862                                       False
# 164716103                                       False
# 164734205                                       False
# 184094199                                       False
# 184181484                                       False
# 184184258                                       False
# 76251593                                         True
# 76251759                                        False
# 80239597                                        False
# 91344922                                        False
# 100261915                                       False
# 100352995                                       False
# 104891289                                       False
# 115208879                                       False
# 191329609                                       False
# 194513437                                       False
# 5504004                                          True
# 120860410                                       False
# 128821360                                       False
# 185493020                                       False
# 185669692                                       False
# 185682216                                       False
# 195825851                                        True
#
# [203694359 rows x 8 columns]

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#            dow  hour  minute  second  ip_os_device_app_hash  \
# 0            0    14      32      21              210218720
# 1            0    14      33      34              808483042
# 2            0    14      34      12              307460829
# 3            0    14      34      52              250305947
# 4            0    14      35       8              950166762
# 5            0    14      36      26               90009919
# 6            0    14      37      44              228641874
# 7            0    14      37      59              261270055
# 8            0    14      38      10              797366259
# 9            0    14      38      23               87040044
# 10           0    14      38      27              703373851
# 11           0    14      38      51              421834599
# 12           0    14      39      29               53350628
# 13           0    14      40      16              525619396
# 14           0    14      40      39              261686900
# 15           0    14      40      51              148285333
# 16           0    14      43      10              422766655
# 17           0    14      43      14              414809083
# 18           0    14      43      25              708420029
# 19           0    14      43      51              801700946
# 20           0    14      44       2              324757871
# 21           0    14      44      15              856957796
# 22           0    14      44      51              900600158
# 23           0    14      44      51              728458752
# 24           0    14      44      52              239525365
# 25           0    14      47      49              103618493
# 26           0    14      48       7              438668861
# 27           0    14      48      55              646730421
# 28           0    14      49      36              118748906
# 29           0    14      49      38              805033446
# ...        ...   ...     ...     ...                    ...
# 203694329    4    15       0       0              752962404
# 203694330    4    15       0       0              549313512
# 203694331    4    15       0       0              548970373
# 203694332    4    15       0       0              205155878
# 203694333    4    15       0       0              801565914
# 203694334    4    15       0       0              693863440
# 203694335    4    15       0       0              688138810
# 203694336    4    15       0       0              564527887
# 203694337    4    15       0       0              839451070
# 203694338    4    15       0       0              313201353
# 203694339    4    15       0       0              157056077
# 203694340    4    15       0       0              892919986
# 203694341    4    15       0       0              894558563
# 203694342    4    15       0       0                7706636
# 203694343    4    15       0       0              278384507
# 203694344    4    15       0       0              535988662
# 203694345    4    15       0       0              278384507
# 203694346    4    15       0       0              659787144
# 203694347    4    15       0       0              809767354
# 203694348    4    15       0       0              392208433
# 203694349    4    15       0       0              581401198
# 203694350    4    15       0       0              262478344
# 203694351    4    15       0       0              228142379
# 203694352    4    15       0       0               61770718
# 203694353    4    15       0       0              989795271
# 203694354    4    15       0       0              840793395
# 203694355    4    15       0       0              648439816
# 203694356    4    15       0       0              454367243
# 203694357    4    15       0       0              122167087
# 203694358    4    15       0       0              811829443
#
#            click_time_second  click_time_interval_ip_device_os_app_hash  \
# 0                      52341                                 1000000007
# 1                      52414                                 1000000007
# 2                      52452                                 1000000007
# 3                      52492                                 1000000007
# 4                      52508                                 1000000007
# 5                      52586                                 1000000007
# 6                      52664                                 1000000007
# 7                      52679                                 1000000007
# 8                      52690                                 1000000007
# 9                      52703                                 1000000007
# 10                     52707                                 1000000007
# 11                     52731                                 1000000007
# 12                     52769                                 1000000007
# 13                     52816                                 1000000007
# 14                     52839                                 1000000007
# 15                     52851                                 1000000007
# 16                     52990                                 1000000007
# 17                     52994                                 1000000007
# 18                     53005                                 1000000007
# 19                     53031                                 1000000007
# 20                     53042                                 1000000007
# 21                     53055                                 1000000007
# 22                     53091                                 1000000007
# 23                     53091                                 1000000007
# 24                     53092                                 1000000007
# 25                     53269                                 1000000007
# 26                     53287                                 1000000007
# 27                     53335                                 1000000007
# 28                     53376                                 1000000007
# 29                     53378                                 1000000007
# ...                      ...                                        ...
# 203694329             399600                                 1000000007
# 203694330             399600                                        469
# 203694331             399600                                       3296
# 203694332             399600                                        382
# 203694333             399600                                      18981
# 203694334             399600                                 1000000007
# 203694335             399600                                         76
# 203694336             399600                                 1000000007
# 203694337             399600                                       4074
# 203694338             399600                                         32
# 203694339             399600                                        152
# 203694340             399600                                 1000000007
# 203694341             399600                                       4026
# 203694342             399600                                        776
# 203694343             399600                                          0
# 203694344             399600                                      36707
# 203694345             399600                                          0
# 203694346             399600                                         32
# 203694347             399600                                      39194
# 203694348             399600                                          7
# 203694349             399600                                       5195
# 203694350             399600                                          0
# 203694351             399600                                      16506
# 203694352             399600                                         29
# 203694353             399600                                         16
# 203694354             399600                                       1305
# 203694355             399600                                      36822
# 203694356             399600                                          0
# 203694357             399600                                 1000000007
# 203694358             399600                                        564
#
#            first_click_interval_ip_device_os_app_hash
# 0                                                True
# 1                                                True
# 2                                                True
# 3                                                True
# 4                                                True
# 5                                                True
# 6                                                True
# 7                                                True
# 8                                                True
# 9                                                True
# 10                                               True
# 11                                               True
# 12                                               True
# 13                                               True
# 14                                               True
# 15                                               True
# 16                                               True
# 17                                               True
# 18                                               True
# 19                                               True
# 20                                               True
# 21                                               True
# 22                                               True
# 23                                               True
# 24                                               True
# 25                                               True
# 26                                               True
# 27                                               True
# 28                                               True
# 29                                               True
# ...                                               ...
# 203694329                                        True
# 203694330                                       False
# 203694331                                       False
# 203694332                                       False
# 203694333                                       False
# 203694334                                        True
# 203694335                                       False
# 203694336                                        True
# 203694337                                       False
# 203694338                                       False
# 203694339                                       False
# 203694340                                        True
# 203694341                                       False
# 203694342                                       False
# 203694343                                       False
# 203694344                                       False
# 203694345                                       False
# 203694346                                       False
# 203694347                                       False
# 203694348                                       False
# 203694349                                       False
# 203694350                                       False
# 203694351                                       False
# 203694352                                       False
# 203694353                                       False
# 203694354                                       False
# 203694355                                       False
# 203694356                                       False
# 203694357                                        True
# 203694358                                       False
#
# [203694359 rows x 8 columns]

# %%
df[["click_time_interval_ip_device_os_app_hash", "first_click_interval_ip_device_os_app_hash"]].to_hdf("../data/click_time_interval_ip_device_os_app_hash.hdf", "click_time_interval_ip_device_os_app_hash")

# %%
gc.collect()
# Out:
# 200

# %% [markdown]
# # Add first click features

# %%
import pandas as pd
df = pd.read_hdf("../data/merged_click_data.hdf", "merged_click_data")

# %%
df["is_attributed"].fillna(0.0, inplace=True)
df["is_attributed"] = (df["is_attributed"] == 1.0)

# %%
df["is_attributed"] = df["is_attributed"].astype("uint8")

# %%
df["click_id"].fillna(1e9+7, inplace=True)

# %%
df["click_id"] = df["click_id"].astype("uint32")

# %%
df.dtypes
# Out:
# app                                              uint16
# channel                                          uint16
# click_id                                         uint32
# device                                           uint16
# ip                                               uint32
# is_attributed                                     uint8
# os                                               uint16
# click_count_by_ip_os_device_dow                  uint32
# click_count_by_ip_os_device_dow_hour             uint16
# click_count_by_ip                                uint32
# dow                                               uint8
# hour                                              uint8
# minute                                            uint8
# second                                            uint8
# rank_by_ip                                       uint32
# rank_by_ip_os_device                             uint32
# rank_by_ip_os_device_dow                         uint32
# click_time_interval_by_ip                       float64
# click_time_interval_by_ip_os_device             float64
# click_time_interval_by_ip_os_device_dow         float64
# click_time_interval_by_ip_os_device_dow_hour    float64
# ip_device_os_cumcount                            uint32
# ip_cumcount                                      uint32
# ip_channel_countuniq                              uint8
# ip_dow_hour_countuniq                             uint8
# ip_app_countuniq                                  uint8
# ip_app_os_countuniq                               uint8
# ip_device_countuniq                              uint16
# app_channel_countuniq                            uint32
# ip_device_os_app_countuniq                       uint32
# ip_dow_hour_count                                uint32
# ip_app_count                                     uint32
# ip_app_os_count                                  uint16
# ip_dow_channel_var                              float32
# ip_app_os_var                                   float32
# ip_app_channel_var                              float32
# ip_app_channel_mean                             float32
# ip_os_device_app_hash                            uint32
# dtype: object

# %%
df["click_time_interval_by_ip"].fillna(1e9+7, inplace=True)
df["click_time_interval_by_ip"] = df["click_time_interval_by_ip"].astype("uint32")
df["click_time_interval_by_ip_os_device"].fillna(1e9+7, inplace=True)
df["click_time_interval_by_ip_os_device"] = df["click_time_interval_by_ip_os_device"].astype("uint32")
df["click_time_interval_by_ip_os_device_dow"].fillna(1e9+7, inplace=True)
df["click_time_interval_by_ip_os_device_dow"] = df["click_time_interval_by_ip_os_device_dow"].astype("uint32")
df["click_time_interval_by_ip_os_device_dow_hour"].fillna(1e9+7, inplace=True)
df["click_time_interval_by_ip_os_device_dow_hour"] = df["click_time_interval_by_ip_os_device_dow_hour"].astype("uint32")

# %%
df.dtypes
# Out:
# app                                              uint16
# channel                                          uint16
# click_id                                         uint32
# device                                           uint16
# ip                                               uint32
# is_attributed                                     uint8
# os                                               uint16
# click_count_by_ip_os_device_dow                  uint32
# click_count_by_ip_os_device_dow_hour             uint16
# click_count_by_ip                                uint32
# dow                                               uint8
# hour                                              uint8
# minute                                            uint8
# second                                            uint8
# rank_by_ip                                       uint32
# rank_by_ip_os_device                             uint32
# rank_by_ip_os_device_dow                         uint32
# click_time_interval_by_ip                        uint32
# click_time_interval_by_ip_os_device              uint32
# click_time_interval_by_ip_os_device_dow          uint32
# click_time_interval_by_ip_os_device_dow_hour     uint32
# ip_device_os_cumcount                            uint32
# ip_cumcount                                      uint32
# ip_channel_countuniq                              uint8
# ip_dow_hour_countuniq                             uint8
# ip_app_countuniq                                  uint8
# ip_app_os_countuniq                               uint8
# ip_device_countuniq                              uint16
# app_channel_countuniq                            uint32
# ip_device_os_app_countuniq                       uint32
# ip_dow_hour_count                                uint32
# ip_app_count                                     uint32
# ip_app_os_count                                  uint16
# ip_dow_channel_var                              float32
# ip_app_os_var                                   float32
# ip_app_channel_var                              float32
# ip_app_channel_mean                             float32
# ip_os_device_app_hash                            uint32
# dtype: object

# %%
df["first_click_by_ip"] = df["click_time_interval_by_ip"]==1e9+7
df["first_click_by_ip_os_device"] = df["click_time_interval_by_ip_os_device"]==1e9+7
df["first_click_by_ip_os_device_dow"] = df["click_time_interval_by_ip_os_device_dow"]==1e9+7
df["first_click_by_ip_os_device_dow_hour"] = df["click_time_interval_by_ip_os_device_dow_hour"]==1e9+7

# %%
df.to_hdf("../data/merged_click_data.hdf", "merged_click_data")

# %% [markdown]
# # Add categorical features

# %% [raw]
# import pandas as pd

# %% [raw]
# %%time
# df = pd.read_feather("../data/basic_table")

# %% [raw]
# %%time
# df["ip_str"] = df["ip"].astype(str)

# %% [raw]
# %%time
# df["os_str"] = df["os"].astype(str)

# %% [raw]
# %%time
# df["device_str"] = df["device"].astype(str)

# %% [raw]
# %%time
# df["app_str"] = df["app"].astype(str)

# %% [raw]
# df.dtypes

# %% [raw]
# %%time
# df["channel_str"] = df["channel"].astype(str)

# %% [raw]
# df["ip_os_device_str"] = df["ip_str"]+" "+df["os_str"]+" "+df["device_str"]

# %% [raw]
# %%time
# df["ip_os_device_app_str"] = (df["ip_str"]+" "
#                               +df["os_str"]+" "
#                               +df["device_str"]+" "
#                               +df["app_str"])

# %% [raw]
# df.dtypes

# %% [raw]
# %%time
# df["ip_os_device_categorical"] = pd.Categorical(df["ip_os_device_str"]).codes

# %% [raw]
# %%time
# df["ip_os_device_app_categorical"] = pd.Categorical(df["ip_os_device_app_str"]).codes

# %% [raw]
# %%time
# df["app_channel_str"] = df["app_str"]+" "+df["channel_str"]

# %% [raw]
# df.dtypes

# %% [raw]
# %%time
# df["app_channel_categorical"] = pd.Categorical(df["app_channel_str"]).codes

# %% [raw]
# df.dtypes

# %% [raw]
# %%time
# df["ip_os_channel_str"] = (df["ip_str"]+" "
#                               +df["os_str"]+" "
#                               +df["channel_str"])

# %% [raw]
# %%time
# df["ip_os_device_channel_str"] = (df["ip_str"]+" "
#                               +df["os_str"]+" "
#                               +df["device_str"]+" "
#                               +df["channel_str"])

# %% [raw]
# df.dtypes

# %% [raw]
# %%time
# df["ip_os_channel_categorical"] = pd.Categorical(df["ip_os_channel_str"]).codes

# %% [raw]
# %%time
# df["ip_os_device_channel_categorical"] = pd.Categorical(df["ip_os_device_channel_str"]).codes

# %% [raw]
# df.dtypes

# %% [raw]
# df.drop(columns=["ip_os_device_str", "ip_os_device_app_str", "app_channel_str", "ip_os_channel_str", "ip_os_device_channel_str"], inplace=True)

# %% [raw]
# df.dtypes

# %% [raw]
# import gc
# gc.collect()

# %% [raw]
# df.dtypes

# %% [raw]
# %%time
# df.sort_index(axis=1, inplace=True)

# %% [raw]
# df

# %% [raw]
# df.dtypes

# %% [raw]
# df["os_device_categorical"] = pd.Categorical(df["os_str"]+" "+df["device_str"]).codes

# %% [raw]
# df["os_device_app_categorical"] =pd.Categorical(
#                                     df["os_str"]+" "+
#                                     df["device_str"]+" "+
#                                     df["app_str"]).codes

# %% [raw]
# df.dtypes

# %% [raw]
# columns = ["ip", "os", "device", "app", "channel"]
# n = len(columns)

# %%
# %%time
import pandas as pd
from logzero import logger
df = pd.read_feather("../data/basic_table")
# Out:
# CPU times: user 892 ms, sys: 1.08 s, total: 1.98 s
# Wall time: 1.98 s

# %%
df.dtypes
# Out:
# app              uint16
# channel          uint16
# click_id         uint32
# device           uint16
# ip               uint32
# is_attributed     uint8
# os               uint16
# dtype: object

# %%
# %%time
logger.info("app")
df["app"] = df["app"].astype(str)
logger.info("os")
df["os"] = df["os"].astype(str)
logger.info("device")
df["device"] = df["device"].astype(str)
logger.info("channel")
df["channel"] = df["channel"].astype(str)
logger.info("ip")
df["ip"] = df["ip"].astype(str)
# Out:
# [I 180429 11:44:23 <timed exec>:1] app
# [I 180429 11:46:59 <timed exec>:3] os
# [I 180429 11:49:35 <timed exec>:5] device
# [I 180429 11:52:03 <timed exec>:7] channel
# [I 180429 11:54:45 <timed exec>:9] ip
# CPU times: user 12min 34s, sys: 32.5 s, total: 13min 6s
# Wall time: 13min 3s

# %%
df.dtypes
# Out:
# app              object
# channel          object
# click_id         uint32
# device           object
# ip               object
# is_attributed     uint8
# os               object
# dtype: object

# %%
columns = ["ip", "os", "device", "app", "channel"]
n = len(columns)

# %%
logger.info("started")
for i in range(n):
    for j in range(i+1, n):
        ci=columns[i]
        cj=columns[j]
        feature="{}_{}".format(ci, cj)
        logger.info("{} started".format(feature))
        df[feature] = pd.Categorical(df[ci]+"_"+df[cj]).codes
        logger.info("{} finished".format(feature))
# Out:
# [I 180429 11:57:27 <ipython-input-6-e942d1df4103>:1] started
# [I 180429 11:57:27 <ipython-input-6-e942d1df4103>:7] ip_os started
# [I 180429 11:59:02 <ipython-input-6-e942d1df4103>:9] ip_os finished
# [I 180429 11:59:02 <ipython-input-6-e942d1df4103>:7] ip_device started
# [I 180429 12:01:06 <ipython-input-6-e942d1df4103>:9] ip_device finished
# [I 180429 12:01:06 <ipython-input-6-e942d1df4103>:7] ip_app started
# [I 180429 12:03:26 <ipython-input-6-e942d1df4103>:9] ip_app finished
# [I 180429 12:03:26 <ipython-input-6-e942d1df4103>:7] ip_channel started
# [I 180429 12:06:17 <ipython-input-6-e942d1df4103>:9] ip_channel finished
# [I 180429 12:06:17 <ipython-input-6-e942d1df4103>:7] os_device started
# [I 180429 12:09:34 <ipython-input-6-e942d1df4103>:9] os_device finished
# [I 180429 12:09:34 <ipython-input-6-e942d1df4103>:7] os_app started
# [I 180429 12:12:54 <ipython-input-6-e942d1df4103>:9] os_app finished
# [I 180429 12:12:54 <ipython-input-6-e942d1df4103>:7] os_channel started
# [I 180429 12:16:14 <ipython-input-6-e942d1df4103>:9] os_channel finished
# [I 180429 12:16:14 <ipython-input-6-e942d1df4103>:7] device_app started
# [I 180429 12:19:31 <ipython-input-6-e942d1df4103>:9] device_app finished
# [I 180429 12:19:31 <ipython-input-6-e942d1df4103>:7] device_channel started
# [I 180429 12:22:51 <ipython-input-6-e942d1df4103>:9] device_channel finished
# [I 180429 12:22:51 <ipython-input-6-e942d1df4103>:7] app_channel started
# [I 180429 12:26:12 <ipython-input-6-e942d1df4103>:9] app_channel finished

# %%
df.dtypes
# Out:
# app               object
# channel           object
# click_id          uint32
# device            object
# ip                object
# is_attributed      uint8
# os                object
# ip_os              int32
# ip_device          int32
# ip_app             int32
# ip_channel         int32
# os_device          int16
# os_app             int16
# os_channel         int16
# device_app         int16
# device_channel     int16
# app_channel        int16
# dtype: object

# %%
import gc
gc.collect()
# Out:
# 133

# %%
twos = ["{}_{}".format(columns[i], columns[j]) for i in range(n) for j in range(i+1, n)]

# %%
for two in twos:
    logger.info("{} {}".format(two, df[two].max()))
# Out:
# [I 180429 12:28:27 <ipython-input-10-80b0f64acc4d>:2] ip_os 3260003
# [I 180429 12:28:28 <ipython-input-10-80b0f64acc4d>:2] ip_device 795046
# [I 180429 12:28:29 <ipython-input-10-80b0f64acc4d>:2] ip_app 4135195
# [I 180429 12:28:30 <ipython-input-10-80b0f64acc4d>:2] ip_channel 8419361
# [I 180429 12:28:31 <ipython-input-10-80b0f64acc4d>:2] os_device 5897
# [I 180429 12:28:32 <ipython-input-10-80b0f64acc4d>:2] os_app 14638
# [I 180429 12:28:33 <ipython-input-10-80b0f64acc4d>:2] os_channel 19725
# [I 180429 12:28:33 <ipython-input-10-80b0f64acc4d>:2] device_app 13140
# [I 180429 12:28:34 <ipython-input-10-80b0f64acc4d>:2] device_channel 11565
# [I 180429 12:28:35 <ipython-input-10-80b0f64acc4d>:2] app_channel 1456

# %%
df.drop(columns=["click_id", "is_attributed"], inplace=True)

# %%
gc.collect()
# Out:
# 104

# %%
df["app"] = pd.Categorical(df["app"]).codes
logger.info("app")
df["os"] = pd.Categorical(df["os"]).codes
logger.info("os")
df["device"] = pd.Categorical(df["device"]).codes
logger.info("device")
df["channel"] = pd.Categorical(df["channel"]).codes
logger.info("channel")
df["ip"] = pd.Categorical(df["ip"]).codes
logger.info("ip")
# Out:
# [I 180429 12:30:30 <ipython-input-13-e56391e1c60f>:2] app
# [I 180429 12:30:57 <ipython-input-13-e56391e1c60f>:4] os
# [I 180429 12:31:19 <ipython-input-13-e56391e1c60f>:6] device
# [I 180429 12:31:39 <ipython-input-13-e56391e1c60f>:8] channel
# [I 180429 12:32:08 <ipython-input-13-e56391e1c60f>:10] ip

# %%
df = df.astype("uint64")

# %%
ones = columns
n = len(ones)

# %%
df.max()
# Out:
# app                   729
# channel               201
# device               3798
# ip                 333167
# os                    855
# ip_os             3260003
# ip_device          795046
# ip_app            4135195
# ip_channel        8419361
# os_device            5897
# os_app              14638
# os_channel          19725
# device_app          13140
# device_channel      11565
# app_channel          1456
# dtype: uint64

# %%
for i in range(n):
    for j in range(i+1, n):
        for k in range(j+1, n):
            feature="{}_{}_{}".format(ones[i], ones[j], ones[k])
            one = ones[i]
            two = "{}_{}".format(ones[j], ones[k])
            logger.info(feature)
            df[feature] = pd.Categorical(df[one]*10000000+df[two]).codes
            logger.info("done")
# Out:
# [I 180429 12:33:12 <ipython-input-17-402fd42ae267>:7] ip_os_device
# [I 180429 12:33:31 <ipython-input-17-402fd42ae267>:9] done
# [I 180429 12:33:31 <ipython-input-17-402fd42ae267>:7] ip_os_app
# [I 180429 12:34:02 <ipython-input-17-402fd42ae267>:9] done
# [I 180429 12:34:02 <ipython-input-17-402fd42ae267>:7] ip_os_channel
# [I 180429 12:34:52 <ipython-input-17-402fd42ae267>:9] done
# [I 180429 12:34:52 <ipython-input-17-402fd42ae267>:7] ip_device_app
# [I 180429 12:35:07 <ipython-input-17-402fd42ae267>:9] done
# [I 180429 12:35:07 <ipython-input-17-402fd42ae267>:7] ip_device_channel
# [I 180429 12:35:28 <ipython-input-17-402fd42ae267>:9] done
# [I 180429 12:35:28 <ipython-input-17-402fd42ae267>:7] ip_app_channel
# [I 180429 12:35:53 <ipython-input-17-402fd42ae267>:9] done
# [I 180429 12:35:53 <ipython-input-17-402fd42ae267>:7] os_device_app
# [I 180429 12:36:01 <ipython-input-17-402fd42ae267>:9] done
# [I 180429 12:36:01 <ipython-input-17-402fd42ae267>:7] os_device_channel
# [I 180429 12:36:09 <ipython-input-17-402fd42ae267>:9] done
# [I 180429 12:36:09 <ipython-input-17-402fd42ae267>:7] os_app_channel
# [I 180429 12:36:17 <ipython-input-17-402fd42ae267>:9] done
# [I 180429 12:36:17 <ipython-input-17-402fd42ae267>:7] device_app_channel
# [I 180429 12:36:25 <ipython-input-17-402fd42ae267>:9] done

# %%
df.max()
# Out:
# app                        729.0
# channel                    201.0
# device                    3798.0
# ip                      333167.0
# os                         855.0
# ip_os                  3260003.0
# ip_device               795046.0
# ip_app                 4135195.0
# ip_channel             8419361.0
# os_device                 5897.0
# os_app                   14638.0
# os_channel               19725.0
# device_app               13140.0
# device_channel           11565.0
# app_channel               1456.0
# ip_os_device           3669417.0
# ip_os_app             23835240.0
# ip_os_channel         43803139.0
# ip_device_app          4795604.0
# ip_device_channel      9446113.0
# ip_app_channel        13206832.0
# os_device_app            32952.0
# os_device_channel        44789.0
# os_app_channel           43287.0
# device_app_channel       19606.0
# dtype: float64

# %%
# %%time
df = df.astype("int64")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <timed exec> in <module>()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4002         # else, only a single dtype is given
#    4003         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4004                                      **kwargs)
#    4005         return self._constructor(new_data).__finalize__(self)
#    4006
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in astype(self, dtype, **kwargs)
#    3460
#    3461     def astype(self, dtype, **kwargs):
# -> 3462         return self.apply('astype', dtype=dtype, **kwargs)
#    3463
#    3464     def convert(self, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3334         bm = self.__class__(result_blocks, axes or self.axes,
#    3335                             do_integrity_check=do_integrity_check)
# -> 3336         bm._consolidate_inplace()
#    3337         return bm
#    3338
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in _consolidate_inplace(self)
#    3829     def _consolidate_inplace(self):
#    3830         if not self.is_consolidated():
# -> 3831             self.blocks = tuple(_consolidate(self.blocks))
#    3832             self._is_consolidated = True
#    3833             self._known_consolidated = True
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in _consolidate(blocks)
#    4851     for (_can_consolidate, dtype), group_blocks in grouper:
#    4852         merged_blocks = _merge_blocks(list(group_blocks), dtype=dtype,
# -> 4853                                       _can_consolidate=_can_consolidate)
#    4854         new_blocks = _extend_blocks(merged_blocks, new_blocks)
#    4855     return new_blocks
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in _merge_blocks(blocks, dtype, _can_consolidate)
#    4874
#    4875         argsort = np.argsort(new_mgr_locs)
# -> 4876         new_values = new_values[argsort]
#    4877         new_mgr_locs = new_mgr_locs[argsort]
#    4878
#
# MemoryError:

# %%
# %%time
df.max()
# Out:
# CPU times: user 27.2 s, sys: 9.12 s, total: 36.3 s
# Wall time: 36.3 s
# app                        729
# channel                    201
# device                    3798
# ip                      333167
# os                         855
# ip_os                  3260003
# ip_device               795046
# ip_app                 4135195
# ip_channel             8419361
# os_device                 5897
# os_app                   14638
# os_channel               19725
# device_app               13140
# device_channel           11565
# app_channel               1456
# ip_os_device           3669417
# ip_os_app             23835240
# ip_os_channel         43803139
# ip_device_app          4795604
# ip_device_channel      9446113
# ip_app_channel        13206832
# os_device_app            32952
# os_device_channel        44789
# os_app_channel           43287
# device_app_channel       19606
# dtype: int64

# %%
# %%time
for i in range(n):
    for j in range(i+1, n):
        for k in range(j+1, n):
            for l in range(k+1, n):
                two1="{}_{}".format(ones[i], ones[j])
                two2="{}_{}".format(ones[k], ones[l])
                feature = "{}_{}".format(two1, two2)
                logger.info(feature)
                df[feature] = pd.Categorical(df[two1]*1000000000+ df[two2]).codes
                logger.info("done")
# Out:
# [I 180429 12:39:00 <timed exec>:8] ip_os_device_app
# [I 180429 12:39:31 <timed exec>:10] done
# [I 180429 12:39:31 <timed exec>:8] ip_os_device_channel
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <timed exec> in <module>()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/categorical.py in __init__(self, values, categories, ordered, dtype, fastpath)
#     328         if dtype.categories is None:
#     329             try:
# --> 330                 codes, categories = factorize(values, sort=True)
#     331             except TypeError:
#     332                 codes, categories = factorize(values, sort=False)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/algorithms.py in factorize(values, sort, order, na_sentinel, size_hint)
#     477         from pandas.core.sorting import safe_sort
#     478         uniques, labels = safe_sort(uniques, labels, na_sentinel=na_sentinel,
# --> 479                                     assume_unique=True)
#     480
#     481     uniques = _reconstruct_data(uniques, dtype, original)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/sorting.py in safe_sort(values, labels, na_sentinel, assume_unique)
#     480     # (Out of bound indices will be masked with `na_sentinel` next, so we may
#     481     # deal with them here without performance loss using `mode='wrap'`.)
# --> 482     new_labels = reverse_indexer.take(labels, mode='wrap')
#     483     np.putmask(new_labels, mask, na_sentinel)
#     484
#
# MemoryError:

# %%
df.dtypes
# Out:
# app                   uint64
# channel               uint64
# device                uint64
# ip                    uint64
# os                    uint64
# ip_os                 uint64
# ip_device             uint64
# ip_app                uint64
# ip_channel            uint64
# os_device             uint64
# os_app                uint64
# os_channel            uint64
# device_app            uint64
# device_channel        uint64
# app_channel           uint64
# ip_os_device           int32
# ip_os_app              int32
# ip_os_channel          int32
# ip_device_app          int32
# ip_device_channel      int32
# ip_app_channel         int32
# os_device_app          int32
# os_device_channel      int32
# os_app_channel         int32
# device_app_channel     int16
# ip_os_device_app       int32
# dtype: object

# %%
df["ip_os_device_app"].max()
# Out:
# 24990688

# %%
df["channel"].max()
# Out:
# 201

# %%
df["ip_os_device_app"] = df["ip_os_device_app"].astype("int64")

# %%
df["ip_os_device_app"] = df["ip_os_device_app"] * 1000

# %%
# %%time
df["ip_os_device_app_channel"] = pd.Categorical(df["ip_os_device_app"]*1000+df["channel"]).codes
# Out:
# CPU times: user 57.8 s, sys: 5.08 s, total: 1min 2s
# Wall time: 1min 2s

# %%
df.dtypes
# Out:
# app                         uint64
# channel                     uint64
# device                      uint64
# ip                          uint64
# os                          uint64
# ip_os                       uint64
# ip_device                   uint64
# ip_app                      uint64
# ip_channel                  uint64
# os_device                   uint64
# os_app                      uint64
# os_channel                  uint64
# device_app                  uint64
# device_channel              uint64
# app_channel                 uint64
# ip_os_device                 int32
# ip_os_app                    int32
# ip_os_channel                int32
# ip_device_app                int32
# ip_device_channel            int32
# ip_app_channel               int32
# os_device_app                int32
# os_device_channel            int32
# os_app_channel               int32
# device_app_channel           int16
# ip_os_device_app             int64
# ip_os_device_app_channel     int32
# dtype: object

# %%
df.drop(columns=["ip", "app", "os", "device", "channel"], inplace=True)

# %%
df.dtypes
# Out:
# ip_os                       uint64
# ip_device                   uint64
# ip_app                      uint64
# ip_channel                  uint64
# os_device                   uint64
# os_app                      uint64
# os_channel                  uint64
# device_app                  uint64
# device_channel              uint64
# app_channel                 uint64
# ip_os_device                 int32
# ip_os_app                    int32
# ip_os_channel                int32
# ip_device_app                int32
# ip_device_channel            int32
# ip_app_channel               int32
# os_device_app                int32
# os_device_channel            int32
# os_app_channel               int32
# device_app_channel           int16
# ip_os_device_app             int64
# ip_os_device_app_channel     int32
# dtype: object

# %%
df.max()
# Out:
# ip_os                       3.260003e+06
# ip_device                   7.950460e+05
# ip_app                      4.135195e+06
# ip_channel                  8.419361e+06
# os_device                   5.897000e+03
# os_app                      1.463800e+04
# os_channel                  1.972500e+04
# device_app                  1.314000e+04
# device_channel              1.156500e+04
# app_channel                 1.456000e+03
# ip_os_device                3.669417e+06
# ip_os_app                   2.383524e+07
# ip_os_channel               4.380314e+07
# ip_device_app               4.795604e+06
# ip_device_channel           9.446113e+06
# ip_app_channel              1.320683e+07
# os_device_app               3.295200e+04
# os_device_channel           4.478900e+04
# os_app_channel              4.328700e+04
# device_app_channel          1.960600e+04
# ip_os_device_app            2.499069e+10
# ip_os_device_app_channel    5.869162e+07
# dtype: float64

# %%
df["ip_os_device_app"] = pd.Categorical(df["ip_os_device_app"]).codes

# %%
df_max = df.max()
df_max
# Out:
# ip_os                        3260003.0
# ip_device                     795046.0
# ip_app                       4135195.0
# ip_channel                   8419361.0
# os_device                       5897.0
# os_app                         14638.0
# os_channel                     19725.0
# device_app                     13140.0
# device_channel                 11565.0
# app_channel                     1456.0
# ip_os_device                 3669417.0
# ip_os_app                   23835240.0
# ip_os_channel               43803139.0
# ip_device_app                4795604.0
# ip_device_channel            9446113.0
# ip_app_channel              13206832.0
# os_device_app                  32952.0
# os_device_channel              44789.0
# os_app_channel                 43287.0
# device_app_channel             19606.0
# ip_os_device_app            24990688.0
# ip_os_device_app_channel    58691622.0
# dtype: float64

# %%
df = df.astype("uint32")

# %%
for c in df_max[df_max < 60000].index:
    logger.info(c)
    logger.info(df[c].max())
    df[c] = df[c].astype("uint16")
# Out:
# [I 180429 12:44:44 <ipython-input-35-a94b67c351ee>:2] os_device
# [I 180429 12:44:46 <ipython-input-35-a94b67c351ee>:3] 5897
# [I 180429 12:44:53 <ipython-input-35-a94b67c351ee>:2] os_app
# [I 180429 12:44:54 <ipython-input-35-a94b67c351ee>:3] 14638
# [I 180429 12:45:02 <ipython-input-35-a94b67c351ee>:2] os_channel
# [I 180429 12:45:03 <ipython-input-35-a94b67c351ee>:3] 19725
# [I 180429 12:45:10 <ipython-input-35-a94b67c351ee>:2] device_app
# [I 180429 12:45:11 <ipython-input-35-a94b67c351ee>:3] 13140
# [I 180429 12:45:18 <ipython-input-35-a94b67c351ee>:2] device_channel
# [I 180429 12:45:19 <ipython-input-35-a94b67c351ee>:3] 11565
# [I 180429 12:45:25 <ipython-input-35-a94b67c351ee>:2] app_channel
# [I 180429 12:45:27 <ipython-input-35-a94b67c351ee>:3] 1456
# [I 180429 12:45:33 <ipython-input-35-a94b67c351ee>:2] os_device_app
# [I 180429 12:45:34 <ipython-input-35-a94b67c351ee>:3] 32952
# [I 180429 12:45:39 <ipython-input-35-a94b67c351ee>:2] os_device_channel
# [I 180429 12:45:41 <ipython-input-35-a94b67c351ee>:3] 44789
# [I 180429 12:45:46 <ipython-input-35-a94b67c351ee>:2] os_app_channel
# [I 180429 12:45:47 <ipython-input-35-a94b67c351ee>:3] 43287
# [I 180429 12:45:52 <ipython-input-35-a94b67c351ee>:2] device_app_channel
# [I 180429 12:45:53 <ipython-input-35-a94b67c351ee>:3] 19606

# %%
df.dtypes
# Out:
# ip_os                       uint32
# ip_device                   uint32
# ip_app                      uint32
# ip_channel                  uint32
# os_device                   uint16
# os_app                      uint16
# os_channel                  uint16
# device_app                  uint16
# device_channel              uint16
# app_channel                 uint16
# ip_os_device                uint32
# ip_os_app                   uint32
# ip_os_channel               uint32
# ip_device_app               uint32
# ip_device_channel           uint32
# ip_app_channel              uint32
# os_device_app               uint16
# os_device_channel           uint16
# os_app_channel              uint16
# device_app_channel          uint16
# ip_os_device_app            uint32
# ip_os_device_app_channel    uint32
# dtype: object

# %%
df.to_feather("../data/multi_basic")
