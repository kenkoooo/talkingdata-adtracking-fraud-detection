# %%
import pandas as pd
import numpy as np

# %%
path = '../../data/'
# file = 'analysis_data.csv'
key = 'sample'

# %%
# %%time
merge = pd.read_hdf(path + key + '.hdf', key=key)
print(merge.shape)
# Out:
# (100000, 32)
# CPU times: user 72 ms, sys: 32 ms, total: 104 ms
# Wall time: 106 ms

# %%
merge.head()
# Out:
#           id  click_id      ip  app  device  os  channel  is_attributed  \
# 0  114898003       NaN  220031   11       1  19      319              0
# 1  114886888       NaN  220031   18       1  19      439              0
# 2  114875904       NaN  220031    3       1  19      489              0
# 3  114882647       NaN  220031   23       1  19      153              0
# 4  114876527       NaN  220031   27       1  19      122              0
#
#    is_test        click_time_ch    ...        click_time_30min  \
# 0        0  2017-11-08 16:19:35    ...     2017-11-08 16:30:00
# 1        0  2017-11-08 16:19:22    ...     2017-11-08 16:30:00
# 2        0  2017-11-08 16:19:08    ...     2017-11-08 16:30:00
# 3        0  2017-11-08 16:19:17    ...     2017-11-08 16:30:00
# 4        0  2017-11-08 16:19:09    ...     2017-11-08 16:30:00
#
#       click_time_15min     click_time_10min      click_time_5min  cnt_1hour  \
# ...
